# %% [markdown]
# # Data Fusion Contest
#
# ## Решение задачи `Goodsification`
#
# * February 2021 - March 2021
# * Александр Широков, [github](https://github.com/aptmess)

# %%
import re
import pickle
import string
import warnings
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import warnings
from download_text import get_grams_from_text
from corus.sources.meta import METAS
from corus.readme import format_metas, show_html, patch_readme
from corus import load_lenta, load_wiki
warnings.filterwarnings("ignore")

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/aptmess/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/aptmess/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /home/aptmess/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /home/aptmess/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Загрузим данные.

# %%
def load_data(path_to_file):
    train = pd.read_parquet(path_to_file)
    map_column_to_type = {
        'category_id': np.int16,
        'item_nds_rate': np.int16,
        'item_price': np.int16,
        'item_quantity': np.float32,
        'receipt_dayofweek': np.int16,
        'receipt_id': np.int32}
    for key in map_column_to_type:
        train[key] = train[key].astype(map_column_to_type[key])
    train = train.drop('brands', axis=1)
    return train

# %%
# %%time
train_data_name = '../../conference_data/data_fusion_train.parquet'
train = load_data(train_data_name)
# Out:
# CPU times: user 1min 40s, sys: 45.4 s, total: 2min 25s
# Wall time: 1min 41s

# %% [markdown]
# Рассмотрим размеченные категории товаров.

# %%
train_data = train[train['category_id'] != -1]

# %% [markdown]
# ### Формирование словаря

# %% [markdown]
# ```bash
# !wget -P ~/IHaskell/word_data/ wget https://dumps.wikimedia.org/ruwiki/latest/ruwiki-latest-pages-articles.xml.bz2
# ```
#
# ```python
# g = get_grams_from_text(path='../../word_data/ruwiki-latest-pages-articles.xml.bz2',
#                         n=[1],
#                         amount_of_sentense=20000,
#                         show_how_much=100,
#                         delete_stop_words=False)
# pickle.dump(g, open("../../word_data/words_wiki_1.pkl", "wb"))
# ```

# %%
word_wiki = get_grams_from_text(path='../../word_data/ruwiki-latest-pages-articles.xml.bz2',
                                n=[1], 
                                amount_of_sentense=200000, 
                                show_how_much=5000, 
                                delete_stop_words=False)

# %%
pickle.dump(word_wiki, open("../../word_data/words_wiki_one_million.pkl", "wb"))

# %% [markdown]
# **Словарь из `train_data`**:
#
# ```python
# unique_values_train__item_name = train['item_name'].unique()
# word = Counter()
# for num, i in enumerate(unique_values_train__item_name):
#     if num % 100000 == 0:
#         print(num)
#     word.update(tokens(i, language='rus'))
# pickle.dump(g, open("../../word_data/words_train.pkl", "wb"))
# ```

# %% [markdown]
# ### Загрузка словаря

# %% [markdown]
# ```python
# g = pickle.load(open("../../word_data/words_wiki_1.pkl", "rb"))
# w = pickle.load(open("../../word_data/words.pkl", "rb"))
# z = pickle.load(open("../../word_data/words_train.pkl", "rb"))
# ```

# %%
g = pickle.load(open("../../word_data/words_wiki_1.pkl", "rb"))
w = pickle.load(open("../../word_data/words.pkl", "rb"))
z = pickle.load(open("../../word_data/words_train.pkl", "rb"))

# %%
COUNTS = w[1] + g[1]

# %% [markdown]
# ## Исправление опечаток / пробелов

# %%
from collections import Counter

def pdist(counter):
    "Превращает частоты из Counter в вероятностное распределение."
    N = sum(list(counter.values()))
    return lambda x: counter[x] / N

P = pdist(COUNTS)
ALPHABET = {'ENG': 'abcdefghijklmnopqrstuvwxyz',
            'RUS': 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'}

def memo(f):
        "Запомнить результаты исполнения функции f, чьи аргументы args должны быть хешируемыми."
        cache = {}
        def fmemo(*args):
            if args not in cache:
                cache[args] = f(*args)
            return cache[args]
        fmemo.cache = cache
        return fmemo


def tokens(text, language):
        shab = r'[a-z]+' if language == 'eng' else r'[а-я]+'
        """Возвращает список токенов (подряд идущих буквенных последовательностей) в тексте. 
           Текст при этом приводится к нижнему регистру."""
        return re.findall(shab, text.lower())





def Pwords(words):
    "Вероятности слов, при условии, что они независимы."
    return product(P(w) for w in words)


def product(nums):
    "Перемножим числа.  (Это как `sum`, только с умножением.)"
    result = 1
    for x in nums:
        result *= x
    return result


def splits(text, start=0, L=29):
    "Вернуть список всех пар (a, b); start <= len(a) <= L."
    return [(text[:i], text[i:]) 
            for i in range(start, min(len(text), L)+1)]


@memo
def segment(text):
    "Вернуть список слов, который является наиболее вероятной сегментацией нашего текста."
    if not text: 
        return []
    else:
        candidates = ([first] + segment(rest) 
                      for (first, rest) in splits(text, 1))
        return max(candidates, key=Pwords)

# %%
un_values = train_data['item_name'].unique()

# %%
segme = {}
for i in un_values:
    spl = tokens(i, language='rus')
    segme[i] = ' '.join([' '.join(segment(tok)) for tok in spl])

# %%
train_data['segme'] = train_data['item_name'].map(segme)

# %% [markdown]
# ## Исправление опечаток

# %%
def correct(word):
    """
    Поиск лучшего исправления ошибки для данного слова.
    
    :param word: слово для исправления
    :return: предрассчитать edit_distance == 0, затем 1, затем 2; в противном случае оставить слово "как есть"
    """
    candidates = (known(edits0(word)) or 
                  known(edits1(word)) or 
                  known(edits2(word)) or 
                  [word])
    return max(candidates, key=COUNTS.get)

# %%
def known(words):
    "Вернуть подмножество слов, которое есть в нашем словаре."
    return {w for w in words if w in COUNTS}

def edits0(word): 
    "Вернуть все строки, которые находятся на edit_distance == 0 от word (т.е., просто само слово)."
    return {word}

def edits2(word):
    "Вернуть все строки, которые находятся на edit_distance == 2 от word."
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

# %%
def edits1(word):
    "Возвращает список всех строк на расстоянии edit_distance == 1 от word."
    pairs      = splits(word)
    deletes    = [a+b[1:]           for (a, b) in pairs if b]
    transposes = [a+b[1]+b[0]+b[2:] for (a, b) in pairs if len(b) > 1]
    replaces   = [a+c+b[1:]         for (a, b) in pairs for c in alphabet if b]
    inserts    = [a+c+b             for (a, b) in pairs for c in alphabet]
    return set(deletes + transposes + replaces + inserts)

def splits(word):
    "Возвращает список всех возможных разбиений слова на пару (a, b)."
    return [(word[:i], word[i:]) 
            for i in range(len(word)+1)]

alphabet = ALPHABET['RUS']

# %%
def correct_text(text, language='rus'):
    text = text.lower()
    "Исправить все слова с опечатками в тексте."
    shab = '[a-zA-Z]+' if language == 'eng' else '[а-яА-Я]+'
    return re.sub(shab, correct_match, text)

def correct_match(match):
    "Исправить слово word в match-группе, сохранив регистр: upper/lower/title."
    word = match.group()
    return case_of(word)(correct(word.lower()))

def case_of(text):
    "Возвращает функцию регистра по тексту: upper, lower, title, или str."
    return (str.upper if text.isupper() else
            str.lower if text.islower() else
            str.title if text.istitle() else
            str)

# %%
un_values_segme = train_data['segme'].unique()

# %%
opechat = {}
for i in un_values_segme:
    opechat[i] = correct_text(i)

# %%
train_data['mistakes_checks'] = train_data['item_name'].map(segme)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = train_data.drop_duplicates('mistakes_checks')

tfidf = TfidfVectorizer(
    max_features=800000, 
    ngram_range=(1, 6), 
    stop_words ='russian',
    analyzer="char_wb", 
    norm = 'l2'
)

x['new'] = x['mistakes_checks'] + ' ' + x['item_name'] + ' ' + x['segme']
X_train = tfidf.fit_transform(x.new)
y_train = x['category_id']
clf = LinearSVC()
folds = KFold(8, 
              shuffle=True, 
              random_state=0)

# %%
predicts = cross_val_predict(clf, 
                             X_train, 
                             y_train, 
                             cv=folds, 
                             n_jobs=8, 
                             method='predict')

# %%
from sklearn.metrics import f1_score

score = f1_score(y_train, predicts, average='weighted')
print(score)
# Out:
# 0.8281417267550237

# %% [markdown]
# В своей работе я сделал ставку на предобработку текста и выуживание из него тех незаметных вещей, которые простые `regex` или токенизация не смогут найти.

# %%
opechat2 = {}
for i in un_values:
    opechat2[i] = corrector.FixFragment(i)
    print(i, '       ', opechat2[i])
# Out:
# Молоко 3,2%,шт         Молоко 3,2%,шт
# Компот из изюма, 114 ккал         Компот из изюма, 114 ккал
# Макаронные изделия отварные (масло сливочное), 240 ккал         Макаронные изделия товарные (масло сливочное), 240 ккал
# Кофе Капучино Большой Эден 18         Кофе Капучино Большой Эден 18
# Хлеб на СЫВОРОТКЕ 350г         Хлеб на СЫВОРОТКЕ 350г
# Сосиска в тесте с сыром 1шт ГЕ         Сосиска в тесте с сыром 1шт ГЕ
# ЛанчБаскет 5 за 300: 2 шт ОРИГ Стрипсы кур фил         ЛанчБаскет 5 за 300: 2 шт ОРИГ Стрипсы кур фил
# Станд Картофель фри         Стан Картофель фри
# Хот-дог Куриный СБ         Хот-дог Куриный СБ
# Чизбургер с луком СБ         Чизбургер с луком СБ
# Бумага туалетная Набер. Челны 1/48         Бумага туалетная Набор. Челны 1/48
# Молоко пастерилиз. т/рекс 2,5 %  1 л. 1/8 БМК         Молоко пастерилиз. т/рекс 2,5 %  1 л. 1/8 БМК
# Пакет         Пакет
# Спинки варено-копченые из мяса ЦБ в/у охладенные         Спинки варено-копченые из мяса ЦБ в/у охлаждение
# Курник 1 шт.         Курник 1 шт.
# ТРК 02 АИ-92-К5         ТРК 02 АИ-92-К5
# Филе бедра куриного жареное 3         Филе бедра куриного жареное 3
# Кофе АМЕРИКАНО средний         Кофе АМЕРИКАНО средний
# 12Р ZEWA ТБ 2СЛ БЕЛАЯ PLUS         12Р ZEWA ТБ 2СЛ БЕЛАЯ PLUS
# 2,7 КГ ЛОСК АВТ КОЛОР         2,7 КГ ЛОСК АВТ КОЛОР
# Вафли с топленым молоком вес. 1кг Тортугалия         Вафли с топленым молоком вес. 1кг Португалия
# Сметана  Кубанский  Молочник  20%  180гр шт         Сметана  Кубанский  Молочник  20%  180гр шт
# Баклажаны 1кг         Баклажаны 1кг
# НЕКТАР МУЛЬТИФРУК КД         НЕКТАР МУЛЬТИФРУК КД
# СМЕТАНА 20% 300Г         СМЕТАНА 20% 300Г
# Брюки трик. женские         Брюки трик. женские
# РОЖОК ЛАК.КОЛИБР100Г         РОЖОК ЛАК.КАЛИБР100Г
# ЧИПСЫ КАРТОФЕЛЬНЫЕ         ЧИПСЫ КАРТОФЕЛЬНЫЕ
# КОКА-КОЛА СТД. СКОМБО         КОКА-КОЛА СТД. КОМБО
# Кф.Золотой Степ 50г с орехом         Кф.Золотой Степ 50г с орехом
# Пирожное Эклер завар./сливки вес         Пирожное Эклер захар./сливки вес
# МОРС 200  мл         МОРС 200  мл
# ЯБЛОКИ АЙДАРЕД         ЯБЛОКИ АЙДАРЕД
# Лепешка Узбекская Акбай  п/п 250 г         Лепешка Узбекская Акбар  п/п 250 г
# Молоко Мудрая хозяйка 2,5% пленка 0,8 л БЗМЖ         Молоко Мудрая хозяйка 2,5% пленка 0,8 л БЗМЖ
# Шампанское Санктъ-Петер п/сл 0,75л 10,5-13%         Шампанское Санкт-Петер п/сл 0,75л 10,5-13%
# Печенье Юбилейное молоко 112г         Печенье Юбилейное молоко 112г
# ГРУША КОНФЕРЕНЦИЯ         ГРУША КОНФЕРЕНЦИЯ
# КРЕКЕР 100Г         КРЕМЕР 100Г
# 400МЛ MRRICCO ORGANIC П/Я67%ДП         400МЛ MRRICCO ORGANIC П/Я67%ДП
# 45Г ГЛ/СЫРКИ РОСТАГРО 20% ВН БЗМЖ         45Г ГЛ/СЫРКИ ПРОСТОГО 20% ВН БЗМЖ
# КД/ЛАВАШ КАВКАЗСКИЙ         КД/ЛАВАШ КАВКАЗСКИЙ
# Kотлета Kуриная Домашняя 100 г         Kотлета Kуриная Домашняя 100 г
# 200Г ЧАЙ ГРИНФИЛД ИНГЛИШ ЭДИШН         200Г ЧАЙ ГРИНФИЛД ИНГЛИШ ЭДИШН
# 230Г СОУС КАЛЬВЕ СЛАДКИЙ ЧИЛИ         230Г СОУС КАЛЬВЕ СЛАДКИЙ ЧИЛИ
# ФИЛЕ ЦБ БЕЗ КОЖИ ПОДЛ (ОХЛ)         ФИЛЕ ЦБ БЕЗ КОЖИ ПОД (ОХЛ)
# 750Г Д/ЧУВС КОШ ИНД ПУРИНА ВАН         750Г Д/ЧУВС КОШ ИНД ПУРИНА ВАН
# Картофель по-деревенски         Картофель по-деревенски
# Салат "Греческий"         Салат "Греческий"
# Биточки Смак из филе птицы 85г, 196ккал         Биточки Смак из филе птицы 85г, 196ккал
# Сигареты Филипп Моррис Компакт Премиум (Филипп Морис)         Сигареты Филипп Моррис Компакт Премиум (Филипп Морис)
# Товар 1         Товар 1
# Товар 5         Товар 5
# Вода негазированная 5л пэт         Вода негазированная 5л пэт
# Лимон Вес..         Лимон Вес..
# Огурец маленький Приморье         Огурец маленький Приморье
# ПЕРЧАТКИ ХОЗ-ЫЕ/КД,S         ПЕРЧАТКИ ХОД-ЫЕ/КД,S
# Кисель, 128 ккал         Кисель, 128 ккал
# Шницель натуральный рубленый из свинины 50г, 183 ккал         Шницель натуральный рубленый из свинины 50г, 183 ккал
# НАПИТОК PEPSI 0,33Л         НАПИТОК PEPSI 0,33Л
# !супрастин таб 25мг n20         !супрастин таб 25мг n20
#               ЕЖ.ПРОК 60+10ШТ                       ЕЖ.ПРОК 60+10ШТ
# Энергет.нап. COMEDY CLUB Энерджи 0,45л         Энергет.нап. COMEDY CLUB Энерджи 0,45л
# Доставка         Доставка
# АНТИФРИЗ FELIX CARBOX КРАСНЫЙ G12+ 5КГ         АНТИФРИЗ FELIX CARBOX КРАСНЫЙ G12+ 5КГ
# Колбаса Докторская 1кг 1сорт п/а Влад стандарт         Колбаса Докторская 1кг 1сорт п/а Влад стандарт
# Яблоки         Яблоки
# Бутылка         Бутылка
# Соус Сырный шт.         Соус Сырный шт.
# Участие в программе лояльности         Участие в программе лояльности
# Колбаса п/к Салями Миланская в/у Бридер         Колбаса п/к Салями Миланская в/у Ридер
# Корнишоны марин с луком Золотая Долина 500мл ст/б         Корнишоны марин с луком Золотая Долина 500мл ст/б
# Хрен столовый Трофимыч 130г Юдинцев         Хрен столовый Трофимов 130г Юдинцев
# Опрыскиватель д/волос парикмахерский ИМП         Опрыскиватель д/волос парикмахерский ИМП
# Напиток из плодов шиповника 200         Напиток из плодов шиповника 200
# Хлеб столичный 37,7         Хлеб столичный 37,7
# GM СОК ЯБЛОЧНЫЙ 0.2Л         GM СОК ЯБЛОЧНЫЙ 0.2Л
# ВАНИЛИН 1,5 Г ХААС         ВАНИЛИН 1,5 Г ХААС
# РАЗРЫХЛИТ ТЕСТА 10Г         РАЗРЫХЛИТ ТЕСТА 10Г
# Печень говяжья         Печень говяжья
# ТЕРАПЕВТИЧЕСКОЕ ЛЕЧЕНИЕ         ТЕРАПЕВТИЧЕСКОЕ ЛЕЧЕНИЕ
# Биойогурт "Козимель" натуральный,шт         Биойогурт "Кромвель" натуральный,шт
# Полотенца универсальные,шт         Полотенца универсальные,шт
# Сок яблоко-морковь прямого отжима,шт         Сок яблоко-морковь прямого отжима,шт
# Сок яблочный, 250 мл,шт         Сок яблочный, 250 мл,шт
# ГУБКА ДЛЯ КАСТРЮЛЬ         ГУБКА ДЛЯ КАСТРЮЛЬ
# ХЛ.ОВС.№2 0,5КГ ЯСНО         ХЛ.ВВС.№2 0,5КГ ЯСНО
# 3) Kофе черный 80 гр.         3) Kобе черный 80 гр.
# Хлеб ржано-пшеничный 200г Погоров         Хлеб ржано-пшеничный 200г Погоров
# САХАР 900 Г ПЕСОК         САХАР 900 Г ПЕСОК
# Хлеб Золотое зернышко 250г нарезка Владхлеб         Хлеб Золотое зернышко 250г нарезка Владхлеб
# ШОК.МОЛ.С МИНД/85Г B         ШОК.МОЛ.С МИД/85Г B
# ИКРА ЦАРСК.ОСОБАЯ220         ИКРА ЦАРСК.ОСОБАЯ220
# Скумбрия 1кг с/м с/г         Скумбрия 1кг с/м с/г
# Продукт кисломолочный Тема Биолакт 3,2% ТБА 208г         Продукт кисломолочный Тема Биолога 3,2% ОБА 208г
# Спаржа с морковью по-корейски         Спаржа с морковью по-корейски
# Картофельное пюре 200г         Картофельное пюре 200г
# Бутылка 1л         Бутылка 1л
# Семечки Джин 140г         Семечки Джин 140г
# КОМПОТ ИЗ АПЕЛЬСИНОВ ПИТАНИЕ РАБОЧИЕ         КОМПОТ ИЗ АПЕЛЬСИНОВ ПИТАНИЕ РАБОЧИЕ
# Каша гречневая рассыпчатая         Каша гречневая рассыпчатая
# САЛАТ ИЗ СВЕКЛЫ С СЫРОМ И ЧЕСНОКОМ ПИТАНИЕ РАБОЧИЕ         САЛАТ ИЗ СВЕКЛЫ С СЫРОМ И ЧЕСНОКОМ ПИТАНИЕ РАБОЧИЕ
# Кисель 200г, 128 ккал         Кисель 200г, 128 ккал
# Котлеты КУРИНЫЕ в панировке ве         Котлеты КУРИНЫЕ в планировке ве
# * Перец сладкий 1кг         * Перец сладкий 1кг
# Масло подсолнечное раф Золотая капелька 870мл пл/б         Масло подсолнечное раф Золотая капелька 870мл пл/б
# ПЕТРУШКА/ПУЧОК 100ГР         ПЕТРУШКА/ПУЧОК 100ГР
# ПЕЧ.К КОФЕ С ШОК ВК         ПЕЧ.К КОФЕ С ШОК ВК
# Рез жев Орбит Белоснежный Баблминт 14г         Рез жев Орбит Белоснежный Баблминт 14г
# Йогурт питьевой Асеньевская фе         Йогурт питьевой Асеньевская фе
# Наполеон         Наполеон
# Колбаса Печёная на дровах в/у Элефант         Колбаса Печёная на дровах в/у Элефант
# Нектар Любимый 0,2л апельсин/манго/мандарин т/п         Нектар Любимый 0,2л апельсин/манго/мандарин т/п
# Лепешка Узбекская 330г Хлеб и Тандыр         Лепешка Узбекская 330г Хлеб и Тандыр
# Колбаса Краковская Даурия п/к в/у 350г         Колбаса Краковская Даурия п/к в/у 350г
# Пиво Старый Мельник из бочонка мягк 0,45л 4,3% ст/б         Пиво Старый Мельник из бочонка мягко 0,45л 4,3% ст/б
# Колбаса Преображенская 300г с/к в/у ЧМПЗ         Колбаса Преображенская 300г с/к в/у ЧМПЗ
# Сыр Российский 1кг 50% Россия БЗМЖ         Сыр Российский 1кг 50% Россия БЗМЖ
# БУЛОЧКА АШАН 30Г         БУЛОЧКА АШАН 30Г
# БУМ АКВАР А3 10Л AS         БУМ АКВА А3 10Л AS
# Блин с Нутеллой 160 гр. 1 шт.         Блин с Эстеллой 160 гр. 1 шт.
# Начинка помидоры свежие 1 порц.         Начинка помидоры свежие 1 пор.
# 0,4 Пепси-кола мал         0,4 Пепси-кола мал
# 0.3 Кофе Американо         0.3 Кофе Американо
# МАКФРЕШ СКОМБО         МАКФРЕШ КОМБО
# Сосиски Филейные в/у 270г Останкино         Сосиски Линейные в/у 270г Останкино
# Компот из св. м.ягоды (клубника или вишня или смород) 200         Компот из св. м.ягоды (клубника или вишня или города) 200
# Картофель запеченный         Картофель запеченный
# Контейнер д/анализов, 100 мл ЕЛМД         Контейнер д/анализов, 100 мл ЕСЛИ
# Т/мыло Заводъ Братьевъ Крестниковыхъ190г         Т/мыло Завод Братьев Крестниковыхъ190г
# Блузка трик. женская         Блузка трик. женская
# Апельсин Вес         Апельсин Вес
# МИНИ-БАГЕТ 125Г         МИНИ-БАГЕТ 125Г
# Вода Три ви н/г 0,5л п         Вода Три ви н/г 0,5л п
# Хлеб Пшеничный в/с  500гр 1/16 Кулахсзян         Хлеб Пшеничный в/с  500гр 1/16 Кулахсзян
# Огурцы короткоплодные,кг         Огурцы короткоплодные,кг
# Сок яблочный 200 мл,шт         Сок яблочный 200 мл,шт
# БАТАРЕЙКИ GP СУПЕР АЛКАЛАЙН 15A-UE4 AA LR6         БАТАРЕЙКИ GP СУПЕР АЛКАЛАЙН 15A-UE4 AA LR6
# НАПИТОК КОКА-КОЛА ГАЗ ПЛ/Б 1Л         НАПИТОК КОКА-КОЛА ГАЗ ПЛ/Б 1Л
# Лакомка со сливочным кремом 90г         Лакомка со сливочным кремом 90г
# Сосиска запеченая в тесте 95г         Сосиска запрещена в тесте 95г
# КАРТОФЕЛЬ ДЛЯ ЖАРКИ MC 2,5 КГ         КАРТОФЕЛЬ ДЛЯ ЖАРКИ MC 2,5 КГ
# Сахар 10гр.         Сахар 10гр.
# Обед Традиционный(250) 1 порц.         Обед Традиционный(250) 1 пор.
# Апельсины импорт 1кг         Апельсины импорт 1кг
# Огурец среднеплодный 1кг         Огурец среднеплодный 1кг
# Свинина вырезка 1кг         Свинина вырезка 1кг
# БАТОН         БАТОН
# Ободок новогодний ИМП         Ободок новогодний ИМП
# ОВОЩИ СВ. ПЕРЕЦ СЛАДКИЙ ЖЕЛТЫЙ 1КГ         ОВОЩИ СВ. ПЕРЕЦ СЛАДКИЙ ЖЕЛТЫЙ 1КГ
# ОВОЩИ СВ. РЕДИС 1КГ         ОВОЩИ СВ. РЕДИС 1КГ
# ПИВО СТАРЫЙ МЕЛЬНИК ИЗ БОЧОНКА МЯГКОЕ СТ/Б 4,3% 0,45Л         ПИВО СТАРЫЙ МЕЛЬНИК ИЗ БОЧОНКА МЯГКОЕ СТ/Б 4,3% 0,45Л
# Курица в кисло-сладком соусе*2         Курица в кисло-сладким соусе*2
# Бананы         Бананы
# Шоколад Твикс Экстра 82г         Шоколад Твикс Экстра 82г
# Горчица столовая 10         Горчица столовая 10
# ЦЕЗАРЬ РОЛЛ         ЦЕЗАРЬ РОЛЛ
# Картофельное пюре (завод) 150г, 137 ккал         Картофельное пюре (завод) 150г, 137 ккал
# Сметана 10г, 16 ккал         Сметана 10г, 16 ккал
# Бусы на ёлку, 4 м ИМП         Бусы на ёлку, 4 м ИМП
# 100Г ГОРЧИЦА ЯДРЕН ТУБА ГЛАВПР         100Г ГОРЧИЦА ЯДРЕ ТУБА ГЛАВА
# 250Г КАРАМЕЛЬ FL МЯТА         250Г КАРАМЕЛЬ FL МЯТА
# 400МЛ MRRICCO ORGANIC ОЛИВ67ДП         400МЛ MRRICCO ORGANIC ОЛИВ67ДП
# ЗЕЛПМ-КА32Х62Х17         ЗАТЕМ-НА32Х62Х17
# Ср-во чист унив Селена Sanitol 500мл         Ср-во чист унив Селена Sanitol 500мл
# Карамель леденц."ВеселыеДольки"микс400г         Карамель леденц."ВеселыеДольки"микс400г
# Кетчуп томатный         Кетчуп томатный
# Купон 5050: 4штКур. крылышки (Баскет Дуэт)         Купон 5050: 4шкУр. крылышки (Банкет Дуэт)
#  К.Ц.Яйца куриные стол.С2 10шт          К.Ц.Яйца куриные стол.С2 10шт
#  Хлеб ПШЕНИЧНЫЙ нар.325г          Хлеб ПШЕНИЧНЫЙ нар.325г
# Капуста         Капуста
# Кофе растворимый Маккофе Original 3в1 20г         Кофе растворимый Марокко Original 3в1 20г
# Мороженое Дакгомз ванильное в глазури 8% рожок 60г         Мороженое Диагноз ванильное в глазури 8% рожок 60г
# ЯЙЦО ЭКСТРА С0         ЯЙЦО ЭКСТРА С0
# ПЕЧ/130Г/ЮБИ         ПЕЧ/130Г/БИ
# ЯЙЦО КУРИНОЕ С1 ВАРА         ЯЙЦО КУРИНОЕ С1 ВАРА
# Йогурт фруктовый "Вишня" 2,5%,шт         Йогурт фруктовый "Вишня" 2,5%,шт
# АССОРТИМЕНТЕ, 300МЛ         АССОРТИМЕНТЕ, 300МЛ
# Жевательная резинка Дирол арбузно-дынный коктейль 14 г         Жевательная резинка Дирол грузино-данный коктейль 14 г
# Сахар песок Мудрая хозяйка авт.фас. 2 кг         Сахар песок Мудрая хозяйка авт.фас. 2 кг
# 20 Г ПРИ-ВА Д/РЫБЫ ВЕГЕТА         20 Г ПРИ-В Д/РЫБЫ ВЕГЕТА
# CLEVER ГРЕЦКИЙ ОРЕХ         CLEVER ГРЕЦКИЙ ОРЕХ
# АБРИКОСЫ 500Г         АБРИКОСЫ 500Г
# КАПУЧИНО         КАПУЧИНО
# Батон Нарезной в/с б/упак 400г Нижегородский         Батон Нарезной в/с б/упак 400г Нижегородский
# Вода мин. негаз. 1.5л пэт Архыз Россия, шт         Вода мин. негаз. 1.5л пэт Архыз Россия, шт
# Батончик БАУНТИ 55г         Батончик БАУНТИ 55г
# Лаваш_         Лаваш_
# Молоко Отборн Грин Агро 3,3-4,3% 1л пэт ГМЗ Артем         Молоко Отбор Грин Агро 3,3-4,3% 1л пэт ГМЗ Артем
# биогая капли детские 5мл фл с дозатором         биогая капли детские 5мл фл с доктором
# Газ вода 0.5 асс         Газ вода 0.5 асс
# Карт.Фри Средн         Карт.Фри Среди
# Твистер из тостера ОСТР СЛ         Твистер из тостера СТР СЛ
# купон 3886: Станд Картофель фри         купон 3886: Стан Картофель фри
# Компот из свежих яблок         Компот из свежих яблок
#          ЧИПСЫ КУКУР В АССОРТ                  ЧИПСЫ КУКУР В АССОРТ
# Friskies, 85, курица ЭСК         Friskies, 85, курица ЭСК
# Сухарики Snack жар.мясо и лук 50г СТМ         Сухарики Snack жар.мясо и лук 50г СТМ
# Контейнер для салатов         Контейнер для салатов
# ЛИПТ ЛИМОН СТ. СКОМБО         ЛИСТ ЛИМОН СТ. КОМБО
# СОУС ГОРЧИЧНЫЙ         СОУС ГОРЧИЧНЫЙ
# ФИЛЕ-О-ФИШ         ФИЛЕ-О-ФИШ
# Жевательная резинка Орбит белоснежный Ба         Жевательная резинка Орбит белоснежный Ба
# САЛАТ САЛАТБАР СЫРНЫЙ С ЧЕСНОКОМ ФАС.         САЛАТ САЛАВАТА СЫРНЫЙ С ЧЕСНОКОМ ФАС.
# Хлеб Кишиневский 550г/Пекарь/         Хлеб Кишиневский 550г/Пекарь/
# Сервелат СПК Фирменный в/к в/у 1кг         Сервелат СПК Фирменный в/к в/у 1кг
# Сосиски СПК Баварские с сыром 1кг         Сосиски СПК Баварские с сыром 1кг
# Молоко ФП пастериз т/топ 2,5 % 1,0л 1/6 Хладокомбинат         Молоко ФП астероид т/топ 2,5 % 1,0л 1/6 Хладокомбинат
# Конфеты Трюфель оригинальный 200гр         Конфеты Трюфель оригинальный 200гр
# Водоотведение         Водоотведение
# Лосось по-Чайхански 120/140         Лосось по-Чайхански 120/140
# МАСЛО 82,5% ЭКОМ.         МАСЛО 82,5% ЭТОМ.
# ШОКОЛАД МОЛОЧНЫЙ BRE         ШОКОЛАД МОЛОЧНЫЙ BRE
# Арахис жареный в скорлупе Панда КНР 300г         Арахис жареный в скорлупе Панда КНР 300г
# Яйцо кур С2 10шт пл/бл Племптицезавод         Яйцо кур С2 10шт пл/бл Племптицезавод
# Байтсы кур фил с соусом Терияки         Байтсы кур фил с соусом Терияки
# ЛанчБаскет 5 за 250: Миринда мал 0.4         ЛанчБаскет 5 за 250: Миранда мал 0.4
# Соус клюквенный         Соус клюквенный
#  Картофель весов,красн,урож          Картофель весов,красно,урон
# ПЕЧЕНЬЕ ОРЕО 95Г         ПЕЧЕНЬЕ ОРЕЛ 95Г
# Мильфей с клубн.тартаром         Миклей с клубн.театром
# Салат Чукка с овощами         Салат Чукка с овощами
# ПЕРЕЦ КРАСНЫЙ         ПЕРЕЦ КРАСНЫЙ
# Напиток Маунтин Дью 1,5л пэт б/сах         Напиток Маунтин Дью 1,5л пэт б/сах
# ПРЕСС.САХАР 1КГ         ПРЕСС.САХАР 1КГ
# Салат с баклажанами, фетой и бальзамическим соусом 200/50         Салат с баклажанами, фетой и бальзамическим соусом 200/50
# КОНСЕРВЫ Д/КОШЕК ФЕЛИКС АППЕТИТНЫЕ КУСОЧКИ С ЛОСОСЕМ В ЖЕЛЕ М/УП 85Г         КОНСЕРВЫ Д/КОШЕК ФЕЛИКС АППЕТИТНЫЕ КУСОЧКИ С ЛОСОСЕМ В ЖЕЛЕ М/УП 85Г
# 100Г ШОКОЛАД АЛЁНКА ФУНД-ИЗЮМ         100Г ШОКОЛАД АЛЁНКА ФОНД-ИЗЮМ
# 250Г ИЗЫСКАНЫЙ БАГЕТ FANFAN         250Г ИЗЫСКАНИЙ БАГЕТ FANFAN
# 330Г СТОЛИЧНЫЙ 1/2 ЧЕРЕМ         330Г СТОЛИЧНЫЙ 1/2 ЧЕРЕЗ
# 700Г КОНФ МИШКА/ АЛЕНКА/ КР.ШАП         700Г КОНФ МИШКА/ АЛЕНКА/ КР.ШАП
# Сосиска в тесте 100г         Сосиска в тесте 100г
# Хлеб " Пшеничный " 1 сорт 0,7 кг.         Хлеб " Пшеничный " 1 сорт 0,7 кг.
# verrum-vit витамины группы в таб n30         verrum-vit витамины группы в таб n30
# хлоргексидина биглюконат средство дл         хлоргексидина биглюконат средство дл
#  Котл"По-киев"Парад"сыр128,в уп          Кот"По-киев"Парад"сыр128,в уп
# КАБАЧКИ         КАБАЧКИ
# БЗМЖ Сыр Сметанковый 45 - 50% 250г кусок Продукты из Елани         БЗМЖ Сыр Сметанковый 45 - 50% 250г кусок Продукты из Мелани
# Вода Кувака 1,5л газ пл/б         Вода Кулака 1,5л газ пл/б
# Конфеты Элль с шок-орех начинкой 1кг КДВ         Конфеты Эль с шок-орех начинкой 1кг КВ
# Вода Кока-Кола 1,0л   *         Вода Кока-Кола 1,0л   *
# Каркаде         Каркаде
# Картофель с грибами         Картофель с грибами
# Хлопья Овсяные Вес         Хлопья Овсяные Вес
# Зажигалка BIC J3 УП 50          Зажигалка BIC J3 УП 50
# СУШКИ 200Г         СУШКИ 200Г
# Сметана 20%,шт         Сметана 20%,шт
# Хлопья кукурузные Любятово 300г м/п         Хлопья кукурузные Любятово 300г м/п
# 3 соуса по цене 2-х: Сырный соус порц. (промо)         3 соуса по цене 2-х: Сырный соус пор. (промо)
# Купон 3072: Стрипсы кф ОР 3шт ПРОМО         Купон 3072: Стрипсы кф ОР 3шт ПРОМО
# Шефбургер Новый СБ         Шефбургер Новый СБ
# ОЛАДЬИ ОВОЩНЫЕ КАПУСТНЫЕ  ООО ШАМСА-МАРКЕТ 100Г         ОЛАДЬИ ОВОЩНЫЕ КАПУСТНЫЕ  ООО ШАНСА-МАРКЕТ 100Г
# ПЛАСТ. ЛОТОК ДЛЯ ЯИЦ ИНТЕРПАК         ПЛАСТ. ЛОТОК ДЛЯ ЯИЦ ИНТЕРФАКС
# ЯЙЦО СТОЛОВОЕ 1КАТ. ПТИЦЕФАБРИКА ПИОНЕРСКОЕ 10ШТ         ЯЙЦО СТОЛОВОЙ 1КАТ. ПТИЦЕФАБРИКА ПИОНЕРСКОЕ 10ШТ
# КАРТОФ.ФРИ СТ. СКОМБО         КАРТОЙ.ФРИ СТ. КОМБО
# Батарейки солевые, 10шт. Тип: АА  ИМП         Батарейки солевые, 10шт. Тип: АА  ИМП
# Говядина в пиве 100г 1 порц.         Говядина в пиве 100г 1 пор.
# ЛАВАШ АРМЯНСКИЙ ООО ШАМСА-МАРКЕТ 340Г         ЛАВАШ АРМЯНСКИЙ ООО ШАНСА-МАРКЕТ 340Г
# Dimax Салф д/пола 80*100 люкс         Dimax Сала д/пола 80*100 люкс
# Конфеты НШФ Сказка Красная шапочка 250г         Конфеты НПФ Сказка Красная шапочка 250г
#                 НАБОР КОРОБОК,2 ШТ                         НАБОР КОРОБОК,2 ШТ
# Ташир кус         Ташир кус
# Перемяч с говядиной         Передач с годичной
# ПАМПУШКА С ЧЕСНОК 30         ПАМПУШКА С ЧЕСНОК 30
# ТВИСТ С ТВОР-ЛИМ НАЧ         ТВИСТ С ТВОР-ЛИМ НАЧ
# 140Г ПРЯНИК ТУЛЬСКИЙ СМОРОДИН         140Г ПРЯНИК ТУЛЬСКИЙ СМОРОДИН
# 370Г ВАРЕНЬЕ АБРИКОС FL         370Г ВАРЕНЬЕ АБРИКОС FL
# 380Г СТУДЕНЬ КЛАССИЧ РУБЛЕВСК         380Г СТУДЕНЬ КЛАССИК РУБЛЕВЫМ
# 85Г ЖАРЕНАЯ КУРИЦА ГУРМЕ ГОЛД.         85Г ЖАРЕНАЯ КУРИЦА ГУРМЕ ГОЛД.
# КОК.М.У/П БАН 200МЛ         КОК.М.У/П БАН 200МЛ
# ТОМАТЫ БАКИНСКИЕ КНОПКА 172         ТОМАТЫ БАКИНСКИЕ КНОПКА 172
# Кондитерская плитка Хорошая комп с арахисом 80г РФ         Кондитерская плитка Хорошая комп с арахисом 80г РФ
# Набор обложек д/днев/тетрад ПВХ 10шт 60мкм Апплика         Набор обложек д/дней/тетрадь ПВХ 10шт 60мкм Публика
# Пластилин 16цв 320г Ушастики Хатбер         Пластилин 16в 320г Ушастики Хатбер
# Сыр с аром топл мол Черный принц 50% Беларусь         Сыр с паром топ мол Черный принц 50% Беларусь
# Тетрадь 12л косая линейка зеленая Гознак         Тетрадь 12л косая линейка зеленая Гознак
# ЖевРез Орбит зимняя свежесть 14г         ЖевРез Орбит зимняя свежесть 14г
# Коктейль детский молочный c шоколадом 2,5%,шт         Коктейль детский молочный c шоколадом 2,5%,шт
# Хлебцы с прованскими травами,шт         Хлебцы с прованскими травами,шт
# Пицца         Пицца
# Хлеб порционный         Хлеб порционный
# МОЛОКО ПМЖЛ 2.5% 900Г         МОЛОКО ПМЖЛ 2.5% 900Г
# ПЕЧЕНЬЕ НА ПОТЕХУ В ШОКОЛАДНОЙ ГЛАЗУРИ 320Г         ПЕЧЕНЬЕ НА ПОТЕХУ В ШОКОЛАДНОЙ ГЛАЗУРИ 320Г
# Хурма  1кг         Хурма  1кг
#  Г/д/д"Фа"тайны/амазонии250мл          Г/д/д"Фа"тайны/амазонии250мл
#  Хворост, вес          Хворост, вес
# * ШАР.Ваф.ВЕН.со взб.сл/виш.150г         * ШАР.Вас.ВЕН.со веб.сл/виш.150г
# Сырники жареные 140 г Уже Гото         Сборник жареные 140 г Уже Гото
# КАРТОФЕЛЬ МЫТЫЙ         КАРТОФЕЛЬ МЫТЫЙ
# ТОМАТЫ ЧЕРРИ ШЕЙКЕР         ТОМАТЫ ЧЕРРИ ШЕЙКЕР
# Спички Балабановские         Спички Балабановские
# Хлеб ТОСТОВЫЙ нарезанный в/с 0         Хлеб ТЕСТОВЫЙ нарезанный в/с 0
# Печенье ТЛ Творожное с изюмом 350г         Печенье ТЛ Творожное с изюмом 350г
# ХЛЕБ СТАНИЧНЫЙ (КУ         ХЛЕБ СТАНИЧНЫЙ (КУ
# Анестезия аппликационная спрей/ гель         Анестезия аппликационная спрей/ гель
# Чай без сахара         Чай без сахара
# Кофе Латте Стандартный Эден 18         Кофе Латте Стандартный Эден 18
# 2Л ГАЗ.НАП ПЕПСИ         2Л ГАЗ.НАП ПЕПСИ
# Магнит символ года ПРЕЗЕНТ         Магнит символ года ПРЕЗЕНТ
# Салат "Первомайский" (огурец св, зел лук) 100         Салат "Первомайский" (огурец св, дел лук) 100
# Соус красный с луком и огурцом 50         Соус красный с луком и огурцов 50
# Колбас, мяс изд-я, запеченные в тесте         Колбас, мчс изд-я, замеченные в тесте
# Напиток клюквенный 200         Напиток клюквенный 200
# Палочки для суши         Палочки для суши
# Чикен Бургер         Чикен Бургер
# Миндальный торт,шт         Миндальный торт,шт
# Мусс творожный с вишней,шт         Мисс творожный с лишней,шт
# Панна-котта "Манго-маракуйя-апельсин",шт         Панна-котта "Манго-маракуйя-апельсин",шт
# ПОМЕЛО         ПОМЕЛО
# Поджарка из говядины 50/15         Поджарка из говядины 50/15
# АРБУЗ         АРБУЗ
# Салат Сельдь под шубой 100гр         Салат Сельдь под шубой 100гр
# КАПУЧИНО БОЛЬШОЙ         КАПУЧИНО БОЛЬШОЙ
# СОУС КИСЛО-СЛАДКИЙ         СОУС КИСЛО-СЛАДКИЙ
# фестал драже n40         фестал драже n40
# ВИНОГРАД ЧЕРНЫЙ         ВИНОГРАД ЧЕРНЫЙ
# ТОМАТЫ ЧЕРРИ РОССИЯ         ТОМАТЫ ЧЕРРИ РОССИЯ
# КОНСЕРВЫ Д/КОШЕК КИТЕКАТ РЫБА В СОУСЕ М/УП 85Г         КОНСЕРВЫ Д/КОШЕК КОМИТЕТ РЫБА В СОУСЕ М/УП 85Г
# ХЛЕБ В/С ДОБРЫЙ ТОСТОВЫЙ В/С ИП МАКАРОВ 500Г         ХЛЕБ В/С ДОБРЫЙ ТЕСТОВЫЙ В/С ИП МАКАРОВ 500Г
# тадалафил-сз таб п/об пленочной 20мг         тадалафил-сз таб п/об пленочной 20мг
#  Колбаса"Докторская"ЦП"400гр          Колбаса"Докторская"ЦП"400гр
# Печенье НОРМА земляничное 400г         Печенье НОРМА земляничное 400г
# 1КГ MC КРЕВ 100/200 КОКТ ОЧИЩ         1КГ MC КИЕВ 100/200 ОКТ ОЧИЩ
# НАПИТОК ADRENALINE         НАПИТОК ADRENALINE
# СОС.ДОКТОРСК./440         СОС.ДОКТОР./440
# Жевательная резинка ОРБИТ XXL Клубника банан 20,4г         Жевательная резинка ОРБИТ XXL Клубника банан 20,4г
# Кинза 50г коррекс Зеленый Сад, шт         Кинга 50г коррекс Зеленый Сад, шт
# Апельсин ЮАР         Апельсин ЮАР
# МЕШКИ Д/МУСОР.30Л,КД         МЕШКИ Д/МУСОР.30Л,КД
# Кальмары под майонезом (тушка) 70         Кальмары под майонезом (тушка) 70
# Сметана 20         Сметана 20
# 400Г БЛИНЫ С МЯСОМ SK         400Г БЛИНЫ С МЯСОМ SK
# БАНАНЫ КНОПКА 18         БАНАНЫ КНОПКА 18
# ЛУК РЕПЧАТЫЙ КНОПКА 134         ЛУК РЕПЧАТЫЙ КНОПКА 134
# МАНГО КНОПКА 41         МАНГО КНОПКА 41
# МАНДАРИНЫ КНОПКА 33         МАНДАРИНЫ КНОПКА 33
# Нектарин 1кг         Нектарин 1кг
# Крем п/доения професс Нежный 150мл         Крем п/доения процесс Нежный 150мл
# Нап.коф. Cappuccino DI TORINO 5шт*25,5г         Нап.коф. Cappuccino DI TORINO 5шт*25,5г
# МЫЛО/90Г         МЫЛО/90Г
# Нектарин КНР         Нектарин КНР
# САЛФЕТКА ВИСКОЗНАЯ         САЛФЕТКА ВИСКОЗНАЯ
#  ОКР.Котлеты ДОМАШНИЕ 450г          ОКР.Котлеты ДОМАШНИЕ 450г
# Яйцо кур С-1 10шт Все вкусное на стол Россия, шт         Яйцо кур С-1 10шт Все вкусное на стол Россия, шт
# Виноград черный,кг         Виноград черный,кг
# Голень цыпленка,кг         Голень цыпленка,кг
# Манго Египет,кг         Манго Египет,кг
# Фарш из говядины 2 сорт охл п/ф         Фарш из говядины 2 сорт охл п/ф
# Морковь мытая КНР         Морковь мытая КНР
# Сыр Мраморный 45% Беларусь         Сыр Мраморный 45% Беларусь
# Хлеб белый (из муки в/с) на закваске 500 г         Хлеб белый (из муки в/с) на закваске 500 г
# ОВОЩИ СВ. ОГУРЦЫ В/УП САХАЛИНСКАЯ ОБЛ. 1КГ         ОВОЩИ СВ. ОГУРЦЫ В/УП САХАЛИНСКАЯ ОБЛ. 1КГ
# Семечки БАБКИНЫ 100г         Семечки БАБКИНЫ 100г
# Салфетка влажная         Салфетка влажная
# Картофель новый урожай 1кг         Картофель новый урожай 1кг
# Томаты розовые вес, кг         Томаты розовые вес, кг
# 1/1 Снуп спрей наз. 0,1% 15мл №1         1/1 Снуп спрей наз. 0,1% 15мл №1
# ФРУКТЫ СВ. БАНАНЫ ЭКВАДОР 1КГ         ФРУКТЫ СВ. БАНАНЫ ЭКВАДОР 1КГ
# Компот из ананасов (консервированных) 200г, 105 ккал         Компот из ананасов (консервированных) 200г, 105 ккал
# Сметана 100г, 159 ккал         Сметана 100г, 159 ккал
# Шаньга с картофелем 100г, 218 ккал (завод)         Шаньга с картофелем 100г, 218 ккал (завод)
# Кабачки вес, кг         Кабачки вес, кг
# Капуста Белокочанная 1кг         Капуста Белокочанная 1кг
# Конфеты ЛЕВУШКА С КАРАМЕЛЬЮ ве         Конфеты ЛЕВУШКА С КАРАМЕЛЬЮ ве
# МАТНАКАШ 400гр         МАТНАКАШ 400гр
# Масло сливочн ДЕРЕВНЯ СЧАСТЛИВ         Масло сливочн ДЕРЕВНЯ СЧАСТЛИВ
# ПОМИДОРЫ НА ВЕТКЕ 1кг         ПОМИДОРЫ НА ВЕТКЕ 1кг
# Хлеб ОКСКИЙ 600гр Узловский ХК         Хлеб ОКСКИЙ 600гр Узловский ХК
# Шпроты в масле крупные 160г ключ ж/б Беринг         Шпроты в масле крупные 160г ключ ж/б Беринг
# 3 шт.Сырные подушечки         3 шт.Сырые подушечки
# ДВОЙНОЙ ЧИЗБУРГЕР         ДВОЙНОЙ ЧИЗБУРГЕР
# КАРТОФЕЛЬ-ФРИ СТД.         КАРТОФЕЛЬ-ФРИ СТД.
# ЧАЙ ЧЕР. ЭРЛ ГРЕЙ БОЛ         ЧАЙ ЧЕР. ЭРЛ ГРЕЙ БОЛ
# МОЛОКО ПАСТЕР 2,5%         МОЛОКО МАСТЕР 2,5%
# Сыр Российский Село Зеленое 50% фас. 250 г БЗМЖ         Сыр Российский Село Зеленое 50% фас. 250 г БЗМЖ
# ХОЛОДНЫЙ ЧАЙ LIPTO         ХОЛОДНЫЙ ЧАЙ LIPTO
# ШОК/90Г/МОЛ         ШОК/90Г/МОЛ
# Печенье "Овсяное", постное 280г,шт         Печенье "Овсяное", постное 280г,шт
# Творог обезжиренный со сметаной,шт         Творог обезжиренный со сметаной,шт
# Молоко коровье питьевое пастериз. 2,5% 1000гр Пюр-Пак         Молоко коровье питьевое астероид. 2,5% 1000гр Пор-Пак
# ГАЗ  (2 ТРК)         ГАЗ  (2 ТРК)
# Кокт Молоч Речка Шоколад 2% БЗМЖ 0,2 МЛ         Окт Молот Речка Шоколад 2% БЗМЖ 0,2 МЛ
# Шампунь Чистая Линия 385/400мл Асс         Шампунь Чистая Линия 385/400мл Асс
# Сок в розлив         Сок в розлив
# КОКА-КОЛА СТД.         КОКА-КОЛА СТД.
# Другой товар         Другой товар
# Лук репчатый нефасованный 1кг         Лук репчатый нефасованный 1кг
# Морковь урожай г 1кг         Морковь урожай г 1кг
# Перчатки БАРХАТ Универсальные,Медит         Перчатки БАРХАТ Универсальные,Медиа
# !перекись водорода р-р д/мест.и нар.         !перекиси водорода р-р и/мест.и на.
# Овощи свеж. Картофель Ред Скарлет нов урож. 1кг (для варки,для салатов)         Овощи свеж. Картофель Ред Скарлет нов урон. 1кг (для варки,для салатов)
# Укроп 100г         Укроп 100г
# Багет с чесн. половинка 175г Россия, шт         Багет с чен. половинка 175г Россия, шт
# СЫРОК С ВАНИЛЬЮ         СРОК С ВАНИЛЬЮ
# СЫРОК СУФЛ СОВ ТРАДИ         СРОК СУАЛ СОВ РАДИ
# ЯБЛОКИ ГОЛДЕН         ЯБЛОКИ ГОЛДЕН
# БЕДРО С/КОЖ Б/КРЕС.Ч. ТМ ПЕТЕЛ         БЕДРО С/КОЖ Б/КРЕС.Ч. ТМ ПЕТЕР
# ТОМАТЫ ЖЕЛТЫЕ КНОПКА 175         ТОМАТЫ ЖЕЛТЫЕ КНОПКА 175
# барбекю         барбекю
# КОНФ.МИНИ НЕСКВИК         КОНФ.МИНИ ДНЕВНИК
# Йогурт десертный ФП земляника 2,5% 180г стакан 1/6         Йогурт десертный ФП земляника 2,5% 180г стакан 1/6
#  Зелень 40г п/п (Пепсико)          Зелень 40г п/п (Епископ)
# ЧЕБУРЕК С МЯСОМ ШТ         ЧЕБУРЕК С МЯСОМ ШТ
# Огурец короткоплодный 1кг         Огурец короткоплодный 1кг
# Напиток газ Кока-кола 1.5л ПЭТ Россия, шт         Напиток газ Кока-кола 1.5л ПЭТ Россия, шт
# Колбаса Сервелат Европейский 350г п/к в/у Дым Дымычъ         Колбаса Сервелат Европейский 350г п/к в/у Дым Дымычъ
# Огурцы среднеплодные 1кг         Огурцы среднеплодные 1кг
# Яйцо шок Киндер-сюрприз 20г Ферреро         Яйцо шок Киндер-сюрприз 20г Ферреро
# 90Г ШОК MILKA МОЛОЧН С ЦЕЛЬН ФУНД         90Г ШОК MILKA МОЛОЧНО С ЦЕЛЬЮ ФОНД
# Соус красный основной 50         Соус красный основной 50
#                НАБОР ПОДКЛАДОК ДЛЯ                        НАБОР ПРОКЛАДКИ ДЛЯ
# Вода негазированная 1,5л пэт         Вода негазированная 1,5л пэт
# Салат Винегрет 130г Фреш         Салат Винегрет 130г Фреш
# Салфетка д/уборки вискоза 30х26см 3шт ЭТО         Салфетка д/уборки виктора 30х26см 3шт ЭТО
# Печенье Юбилейное традиционное 112г ФП         Печенье Юбилейное традиционное 112г ФП
# ХЛЕБ ПШЕНИЧНЫЙ РУЧНОЙ ШАМСА-МАРКЕТ 450Г         ХЛЕБ ПШЕНИЧНЫЙ РУЧНОЙ ШАНСА-МАРКЕТ 450Г
# Сгущенка с сах  Любавинка 8,5% 500г пэт         Сгущенка с сах  Любовника 8,5% 500г пэт
# Контейнер 500гр         Контейнер 500гр
# Горошек Вернет 425мл ж/б         Горошек Вернет 425мл ж/б
# ПЕЧЕНЬЕ 100Г         ПЕЧЕНЬЕ 100Г
# СТРУДЕЛЬ С КЛУБНИК         СТРЕЛЬБЫ С КЛУБНИ
# УЛИТКА С КУРИЦЕЙ         УЛИТКА С КУРИЦЕЙ
# Купон 3844: Шефбургер Де Люкс СБ         Купон 3844: Шефбургер Де Люкс СБ
# 4582 ФАРШ ГОВЯЖИЙ 1КГ ПФ         4582 ФАРШ ГОВЯЖИЙ 1КГ ПФ
# Сигареты Честерфилд легкий (500) 149 (ФМ)          Сигареты Честерфилд легкий (500) 149 (ФМ)
# Заливное По-домашнему 500г Ратимир         Заливное По-домашнему 500г Ратимир
# Колбаса вар Докторская 470г в/с иск/об Ратимир         Колбаса вар Докторская 470г в/с иск/об Ратимир
# ТОМАТЫ         ТОМАТЫ
# Гранат Турция         Гранат Турция
# БЕКОН С/К НАР.500Г         БЕКОН С/К НАР.500Г
# ВЛАЖ.САЛФ.Д/ДЕТ 20ШТ         ВЛАД.САЛА.Д/ДЕТ 20ШТ
# ЗРАЗЫ НАТУР.ИНД.0,5         ФРАЗЫ НАТУР.ИНД.0,5
# Картофельное пюре         Картофельное пюре
# ЦИКОРИЙ НАТ.СУБЛ.85Г         ИСТОРИЙ НАТ.СУБД.85Г
#  Салат листовой в горшочке 1шт          Салат листовой в горшочке 1шт
# Картофель фри мал.         Картофель фри мал.
# Сэвен-Ап Мохито         Свен-Ап Мохито
# Сыр творожный "Cremette" 65%  800гр         Сыр творожный "Cremette" 65%  800гр
# БАТОН НОВЫЙ В/С 0,380кг         БАТОН НОВЫЙ В/С 0,380кг
# визмед мульти гидрогель офтальмологический 10мл         взамен мульти гидрогель офтальмологический 10мл
# КАБАЧКИ ВЕСОВЫЕ         КАБАЧКИ ВЕСОВЫЕ
# КАПУСТА ПЦ ВЕС         КАПУСТА ПЦ ВЕС
# КД/ТОМАТНАЯ ПАСТА 70         КД/АВТОМАТА ПАСТА 70
# РИС КРУГЛЫЙ 800Г         РИС КРУГЛЫЙ 800Г
# ФИЛЕ БЕДРА ИНД. ВУ Г         ФИЛЕ БЕДРА ИНД. В Г
#  Водка ПЯТЬ ОЗЕР 40% 0.5л          Водка ПЯТЬ ОЗЕР 40% 0.5л
#          СОКОСОДЕРЖ. НАП. МУЛ                  СОКОСОДЕРЖ. НАП. УЛ
# Леденцы ХОЛЛС Ментол Экстра 24.5г         Леденцы ХОЛЛ Ментол Экстра 24.5г
# Сосиски Детские 300г Волгоградский МК         Сосиски Детские 300г Волгоградский МК
# 100Г ШОК RITTER РОМ ОРЕХ ИЗЮМ         100Г ШОК RITTER РОМ ОРЕХ ИЗЮМ
# МАКАРОНЫ GE МЕЛКАЯ ЛАПША 350Г         МАКАРОНЫ GE МЕЛКАЯ ЛАПША 350Г
#  Грибы ШАМПИНЬОНЫ 250г          Грибы ШАМПИНЬОНЫ 250г
# Батончик СНИКЕРС Криспер 40г         Батончик СНИКЕРС Криспер 40г
# Стики HEETS Оранжевые селекшен         Стики HEETS Оранжевые селекшен
# Сахар пресованный 250г в асс         Сахар пресованный 250г в асс
# !кетонал таб п/об пленочной 100мг n20         !кантона таб п/об пленочной 100мг n20
# evitest тест-полоска для определения беременност         evitest тест-полоска для определения беременности
# ЖЕВ.КОНФЕТЫ ФРУТТЕЛА АССОРТИ 41Г         ЖЕВ.КОНФЕТЫ ФРУТТЕЛА АССОРТИ 41Г
# Лук репчатый весовой         Лук репчатый весовой
# Шамп Росс Салют Златоглав бел п/сл 0,75л 10,5-13%         Шамп Росс Салют Златоглав бел п/сл 0,75л 10,5-13%
# Браслет зеленый         Браслет зеленый
# М-З МОСК ПРОВ С ДОЗ         М-З МОСК ПРОВ С ДОЗ
# МОЛОКО 1Л УЛЬТРАПАСТ         МОЛОКО 1Л УЛЬТРАПАСТ
# КОНД.Д/БЕЛЬЯ ЦВЕТ.1Л         ФОНД.Д/БЕЛЬЯ ЦВЕТ.1Л
# САЛФ ВЛ ГИГ-Е 80Ш КД         САЛА ВЛ ГИГ-Е 80Ш КД
# ОГУРЕЦ СРЕДНИЙ ГЛАДК         ОГУРЕЦ СРЕДНИЙ ГЛАДКО
# ЯГОДА СВ. ВИНОГРАД БАЯН ЗЕЛЕНЫЙ 1КГ         ЯГОДА СВ. ВИНОГРАД БАЯН ЗЕЛЕНЫЙ 1КГ
# Каша пшеничная на молоке 200         Каша пшеничная на молоке 200
# Сельдь с луком 1/30         Сельдь с луком 1/30
# Водоотв. на СОИ         Заводов. на СОИ
# ГВС на СОИ         ГВС на СОИ
# Содержание жилья         Содержание жилья
# Продукт кисломолочный Закваска 1,5% (буфет)         Продукт кисломолочный Закваска 1,5% (буфет)
# ВОДА НЕГАЗИРОВ.0,5         ВОДА НЕГАЗИРОВ.0,5
# ГОРЧИЦА 100Г         ГОРЧИЦА 100Г
# Батон Нарезной 400г Челны-хлеб         Батон Нарезной 400г Челны-хлеб
# Хлеб Гречневый  300г Пр-во         Хлеб Гречневой  300г Пр-во
# Томаты         Томаты
# !милдронат капс. 250мг n40         !милдронат касс. 250мг n40
# фезам капс. 400мг+25мг n60         фезам касс. 400мг+25мг n60
# Окорочка жареные         Окорочка жареные
# Морс в ассорт.         Морс в ассорт.
# Сосиски ТОРГОВАЯ ПЛОЩАДЬ Колобас-Балабас в/у 350г         Сосиски ТОРГОВАЯ ПЛОЩАДЬ Колобас-Балабас в/у 350г
# Напиток Тархун среднегаз 1,5л Корфовский 1/6         Напиток Тархун среднего 1,5л Корфовский 1/6
# Пиво "Челябинское Чешское Традиционное 1*30"Балтика/Самара         Пиво "Челябинское Чешское Традиционное 1*30"Балтика/Самара
# Язычки 80г.ЛаМель.Россия, шт         Языки 80г.ЛаМель.Россия, шт
# Ягодный пунш         Ягодный пунш
# Пирожок с капустой         Пирожок с капустой
# Говядина Ароматная в/у Ратимир         Говядина Ароматная в/у Ратимир
# Печенье RC прот.кокос низ/калл 50г         Печенье RC прот.кокос низ/карл 50г
# Сардельки Говяжьи Элефант газ/уп         Сардельки Говяжьи Элефант газ/уп
# Средство моющ д/пола/стен Mr.Proper Лимон 1л         Средство мою д/пола/стен Mr.Proper Лимон 1л
# Фруктовые кусочки Ф няня Осьминожки ябл/клубн 16г         Фруктовые кусочки Ф няня Осьминожки ябл/клубн 16г
# Шоколад Киндер Буэно Т30 43г         Шоколад Киндер Буэно Т30 43г
# Шоколад молочный карамель арахис 90г         Шоколад молочный карамель арахис 90г
#  Взрослый 5 ч. выходной именинник          Взрослый 5 ч. выходной именинник
# КОЛБ.ДОКТОРСКАЯ 500Г         КОЛБ.ДОКТОРСКАЯ 500Г
# Макаронные изделия отварные (масло сливочное) 150г, 246 ккал         Макаронные изделия товарные (масло сливочное) 150г, 246 ккал
# СВИНИНА МЯКОТЬ (ОКОРОК БЕЗ КОСТИ) ПФ МЯСНОЙ         СВИНИНА МЯКОТЬ (ОКОРОК БЕЗ КОСТИ) ПФ МЯСНОЙ
# ЦЫПЛЕНОК 1 КГ БРОЙЛЕР ОХЛАЖДЕННЫЙ         ЦЫПЛЕНОК 1 КГ БРОЙЛЕР ОХЛАЖДЕННЫЙ
# КД/ОГУРЦЫ МАРИН.700Г         КД/ОГУРЦЫ МАРИН.700Г
# Коса маковая упак. п/п 300г Челны-хлеб         Коса таковая упак. п/п 300г Челны-хлеб
# Рожки Алтайские упак. п/п 150г Челны-хлеб         Рожки Алтайские упак. п/п 150г Челны-хлеб
# Творог 5% 280г шайба Серышевский         Творог 5% 280г шайба Серышевский
# Пиво "Факс " премиум светлое 4,9% 0,45л. ж/б         Пиво "Факс " премиум светлое 4,9% 0,45л. ж/б
# 1/1 Ибупрофен таб. п.п.о. 400мг         1/1 Ибупрофен таб. п.п.о. 400мг
# МАРКЕР ТЕКСТ.РОЗОВЫЙ         МАРКЕР ТЕКСТ.РОЗОВЫЙ
# Печенье Трюфельное классическое 300г П/К         Печенье Трюфельное классическое 300г П/К
# ЖМ ДЕТСКОЕ ЧЕРЕДА         ЖЕ ДЕТСКОЕ ЧЕРЕДА
# З/П ОТБЕЛ.ПЛЮС 100МЛ         З/П ОТДЕЛ.ПЛЮС 100МЛ
# Десерт Bonjour в ассорт.232гр.Конти         Десерт Bonjour в ассорт.232гр.Конти
# газоснабжение         газоснабжение
#          КОНФЕТЫ 'КАРТОШКА' 2                  КОНФЕТЫ 'КАРТОШКА' 2
# Пиво Мотор Крепкое 0,9л ПЭТ8%МПК         Пиво Мотор Крепкое 0,9л ПЭТ8%МПК
# Кисл/мол продукт БиоМакс 450г 1,0% кефирный пл/б ВБД БЗМЖ         Касл/мол продукт БиоМакс 450г 1,0% камерный пл/б ВБД БЗМЖ
# 400Г БАТОН НАРЕЗНОЙ В/С НАРЕЗ         400Г БАТОН НАРЕЗНОЙ В/С НАРЕЗ
# RED BULL 0,355Л Ж/Б         RED BULL 0,355Л Ж/Б
# СИГАРЕТЫ ЯВА 100 ЗОЛОТАЯ КЛАССИЧЕСКАЯ         СИГАРЕТЫ ЯВА 100 ЗОЛОТАЯ КЛАССИЧЕСКАЯ
# Огурцы 1 кат.         Огурцы 1 кат.
# ЯБЛОКИ ГОЛДЕН ВЕСОВ         ЯБЛОКИ ГОЛДЕН ВЕСОВ
# КД/НЕКТАР АПЕЛЬС.2Л         КД/НЕКТАР АПРЕЛЯ.2Л
# СТ ПОР АВТ СВЕЖ ЛАВА         СТ ПОР АВТ СВЕЖ ЛАВА
# БатонЩЕЛКОВСК38гнар          БатонЩЕЛКОВСК38гнар
# Салат из моркови с яблоками         Салат из моркови с яблоками
# ЙогуртНежныйПерсикБЗМЖ5% 110г ван         ЙогуртНежныйПерсикБЗМЖ5% 110г ван
# Отбеливатель Белизна 1000мл         Отбеливатель Белизна 1000мл
# 800Г ХАЛВА РОТ ФРОНТ         800Г ХАЛВА РОТ ФРОНТ
# Батончик Раз Два 30г Славянка         Батончик Раз Два 30г Славянка
# Арбуз         Арбуз
# ЧИПСЫ МАЛОСОЛ.ОГУРЧ         ЧИПСЫ МАЛОГО.МОГУТ
#  Батон НАРЕЗНОЙ нарезка п/э 380г          Батон НАРЕЗНОЙ нарезка п/в 380г
# Зелёный горошек С&B 310гр. СТМ         Зелёный горошек С&B 310гр. СТМ
# Конфеты Марсианка тирамису 200гр.         Конфеты Марианна тиражами 200гр.
# Конфеты"Ореховое царство" 300гр.Невс         Конфеты"Ореховое царство" 300гр.Нес
# Чай черн. Принцесса ГИТА 1,2гХ100пак         Чай черн. Принцесса ГИТА 1,2иХ100пак
# ГРИБЫ ВЕШЕНКА ФАС350         ГРИБЫ ВЕШЕНКА ФАС350
# A18ADESOM03-AB 43-46 Носки для фитнеса (3 пары) Fitness socks (3 pairs) серый/черный р.43-46         A18ADESOM03-AB 43-46 Носки для фитнеса (3 пары) Fitness socks (3 pairs) серый/черный р.43-46
# Груша Аббат вес, кг         Груша Аббат вес, кг
# Пицца Карбонара кусок 125г         Пицца Карбонара кусок 125г
# Яблоки Гренни вес, кг         Яблоки Гребни вес, кг
# ОВОЩИ СВ. ЛУК РЕПЧАТЫЙ 1КГ         ОВОЩИ СВ. ЛУК РЕПЧАТЫЙ 1КГ
# Премиум аромат         Премиум аромат
# Голень куриная         Голень куриная
# Вл.салф.с мицелл.водой 60шт ЗТ         Вл.сала.с мицелл.водой 60шт ЗА
# Кондиционер Vernel Свежий бриз 1820мл         Кондиционер Vernel Свежий бриз 1820мл
# Крупа манная Агроальянс Классик 800г         Крупа манная Агроальянс Классик 800г
# Мука Мельник 1кг         Мука Мельник 1кг
# Пиво Балтика №0 0,45л алк 0,45% ж/б         Пиво Балтика №0 0,45л алк 0,45% ж/б
# 150МЛ OLD SPICE АЭР SLUGGER         150МЛ OLD SPICE АЭР SLUGGER
# 85Г ПЛЕЖЕР ФОРЕЛЬ/КРЕВ  ШЕБА         85Г ПЛЕЕР ФОРЕЛЬ/КИЕВ  ШЕБА
# Печень свиная         Печень свиная
# СЫР МААСДАМ 45%         СЫР МААСДАМ 45%
# Сухой завтрак Шарики шоколадные Любятово 200г м/п         Сухой завтрак Шарики шоколадные Любятово 200г м/п
# Дрожжи хлебопекарные САФ-НЕВА Люкс экстра пресованные 100г         Дрожжи хлебопекарные САФ-НЕВА Люкс экстра арестованные 100г
# Хлеб ИНСКОЙ Деревенский нарезка 350г         Хлеб ИНСКОЙ Деревенский нарезка 350г
# МЯЧ, 6ЦВ. В АСС.-ТЕ         МЯЧ, 6ЦВ. В АСС.-ТЕ
# СОС.КЛАССИЧЕСКИЕ СО         СОС.КЛАССИЧЕСКИЕ СО
# Компот из яблок         Компот из яблок
# асвитол солнышко таб жев. 25мг n10         развито солнышко таб жев. 25мг n10
# Морс Клюква 200 мл         Морс Клюква 200 мл
# Компот Ассорти         Компот Ассорти
# Батон нарезной ФР пекарни*         Батон нарезной ФР пекарни*
# Молоко 0,95л 3,2% пл/б МолКом БЗМЖ         Молоко 0,95л 3,2% пл/б ПолКом БЗМЖ
# Яйцо С2 1шт         Яйцо С2 1шт
# СМЕТАНА 15% РАЭ 320Г         СМЕТАНА 15% РАЭ 320Г
# Багет Мини 150г Артель         Багет Мини 150г Артель
# Мак изд № ракушка Шебекенские 450г         Мак изд № ракушка Шебекенские 450г
# СОЛЬ ПОВАРЕНАЯ ПИЩЕВАЯ №1 В/С ИЛЕЦКАЯ ПАЧ 1КГ         СОЛЬ ПОВАРЕНАЯ ПИЩЕВАЯ №1 В/С ЛЕГКАЯ ПАР 1КГ
#  АНАК.Верм.с кур.бул.б/пр 60г          АНАК.Верм.с кур.бул.б/пр 60г
# Конверт песочный с черной смор         Конверт песочный с черной смог
# КОКА-КОЛА 1.5Л         КОКА-КОЛА 1.5Л
#  МОРЕМ.Форель п/к ф/к 180г          МОРЕМ.Форель п/к ф/к 180г
# Отопление-мощность         Отопление-мощность
# 1/1 Верошпирон таб. 25мг №20         1/1 Верошпирон таб. 25мг №20
#  АЮТИН.ХЛЕБ ХлебБОРОДрж-пшен330г          АЮТИН.ХЛЕБ ХлебБОРОДрж-плен330г
# Шоколад РОССИЯ молочный карамель арахис 90г         Шоколад РОССИЯ молочный карамель арахис 90г
# Улитка с корицей         Улитка с корицей
# КД/МАСЛО ПОДСОЛНЕЧН         КД/МАСЛО ПОДСОЛНЕЧН
# СЫР КОСТРОМСКОЙ 45%         СЫР КОСТРОМСКОЙ 45%
# ХЛЕБ РЖЕВСКИЙ 700Г.         ХЛЕБ РЖЕВСКИЙ 700Г.
# Жевательная резинка Орбит Bubblemint белоснежный 13,6 г         Жевательная резинка Орбит Bubblemint белоснежный 13,6 г
# Филе куриное из красного мяса охл 1кг         Филе куриное из красного мяса охл 1кг
# Хлебцы Хлебцы-молодцы бородинские 150г Молодец         Хлебцы Хлебцы-молодцы бородинские 150г Молодец
# 390Г БОРОДИН.ПОЛОВИНКА НАРЕЗКА         390Г БОРОДИН.ПОЛОВИНКА НАРЕЗКА
# ГОЛУБИКА, 125 Г         ГОЛУБИКА, 125 Г
# ФИЛЕ БЕДРА Б/К ЦБ ОХЛ ПОДЛ         ФИЛЕ БЕДРА Б/К ЦБ ОХЛ ПОД
# Блинчик с творогом         Блинчики с которого
# ВТОРОЕ БЛЮДО         ВТОРОЕ БЛЮДО
# ГАРНИР         ГАРНИР
# МУЧНЫЕ БЛЮДА         РУЧНЫЕ БЛЮДА
# Салат из б/ капусты с перцем, луком зел 100         Салат из б/ капусты с перцем, луком дел 100
# ШОКОЛАД АЛЬПЕН ГОЛД КЛУБНИКА/ЙОГУРТ 90Г         ШОКОЛАД АЛЬПЕН ГОЛД КЛУБНИКА/ЙОГУРТ 90Г
# Хлеб подовой  0,6 кг Х/з "Наримановский", шт         Хлеб годовой  0,6 кг Х/з "Наримановский", шт
# Булочка пшеничная         Булочка пшеничная
# Беляш 120гр 1шт ГЕ С         Беляш 120гр 1шт ГЕ С
# Сосиска в тесте         Сосиска в тесте
# 1/1 Димексид конц. д/р-ра наружн. 100мл         1/1 Диоксида конц. д/р-ра наружу. 100мл
# аскорил экспекторант сироп 100мл фл         ускорил экспекторант сироп 100мл фл
# тантум верде спрей д/мест.пр. 0.255мг/доза 30мл         станет верде спрей д/мест.пр. 0.255мг/доза 30мл
# Пицца Грибная кусок 130г         Пицца Грибная кусок 130г
# Сахарный песок 900г.         Сахарный песок 900г.
# Винегрет  кг         Винегрет  кг
# бинт марлев.стер. 7мx14см         бинт марлен.стер. 7мx14см
# стм валериана экстра таб n45         стм валериана экстра таб n45
# 1,8Г*25 ЧАЙ ГРИНФ. ПИЧ МЭЛЛОУ         1,8Г*25 ЧАЙ ГРИН. ПИЧ МЭЛЛОУ
# 250Г ПЕЧЕНЬЕ ОВСЯНОЕ ЛЮБЯТОВО         250Г ПЕЧЕНЬЕ ОВСЯНОЕ ЛЮБЯТОВО
# Молоко ИРМЕНЬ пастер 3,2% т/пак 950мл         Молоко ИРМЕНЬ мастер 3,2% т/пак 950мл
# Кефир ИРМЕНЬ 2.5% 950г         Кефир ИРМЕНЬ 2.5% 950г
# Коф напит ЛБ Капучино 240         Коф напит ЛБ Капучино 240
# Кока-кола 0,5л.         Кока-кола 0,5л.
# СЫР МОЦАРЕЛЛА(АРГЕН)         СЫР МОЦАРЕЛЛА(АРСЕН)
# !омез капс. киш.раств. 20мг n30         !омез касс. киш.расти. 20мг n30
# КОНДИТЕРСКИЕ ИЗДЕЛИЯ ВЕС.         КОНДИТЕРСКИЕ ИЗДЕЛИЯ ВЕС.
# РУЛЕТ ПЫШКИН ДОМ КЛУБНИЧНЫЙ 200Г         РУЛЕТ ПУШКИН ДОМ КЛУБНИЧНЫЙ 200Г
# 38Г ОРЕО ПЕЧЕНЬЕ         38Г ОРЕЛ ПЕЧЕНЬЕ
# ВЛАЖ.САЛФ.ДЛЯ ЛИЦ КД         ВЛАД.САЛА.ДЛЯ ЛИЦ КД
# ДЕЗ.ШАР ULTRA 50 NIV         ДЕЗ.ШАР ULTRA 50 NIV
# ОБЛ Д/Т 350Х210ММ 10         ОБЛ Д/Т 350Х210ММ 10
# ХЕК ФИЛЕ (МЕДАЛЬОНЫ) С/М         ХЕК ФИЛЕ (МЕДАЛЬОНЫ) С/М
# 700МЛ МАЙОНЕЗ МОСК.ПРОВ 67% ДП         700МЛ МАЙОНЕЗ МОСК.ПРОВ 67% ДП
# HALLS АРБУЗ 25Г         HALLS АРБУЗ 25Г
# Драники         Драники
# 1/1 Мидокалм таб. п.п.о. 50мг №30         1/1 Мидокалм таб. п.п.о. 50мг №30
# пирожок с печенью в/с 75гр         пирожок с печенью в/с 75гр
# Рассольник Лениградский перловкой 250         Рассольник Ленинградский орловской 250
# ПРОДУКТ ЙОГУРТНЫЙ УСЛАДА КЛУБНИКА 1,2% ЭРМАНН 320Г         ПРОДУКТ ЙОГУРТНЫЙ УСЛАДА КЛУБНИКА 1,2% ЭРМАНН 320Г
# БЕДРА КУРИНЫЕ         БЕДРА КУРИНЫЕ
# КУС КУРИЦА 85Г ФЕЛИК         КУС КУРИЦА 85Г ФЕЛИКС
# НАПОЛН Д/КОШ ТУАЛ         НАПОЛИ Д/КОШ ТУЛА
# Выпечка Круассан французский C         Выпечка Кузбасса французский C
# Драже Skittles 2в1 38г.         Драже Skittles 2в1 38г.
# Драже Рондо Лимон 30г.         Драже Рондо Лимон 30г.
# Чипсы Карт Московский вкус лисичек 30г         Чипсы Карт Московский вкус лисичек 30г
# Котлета куриная         Котлета куриная
# Рис отварной 150гр.         Рис отварной 150гр.
# Биотворог детский с вишней 4,2%,шт         Биотворог детский с лишней 4,2%,шт
#  Молоко 3,2% 0,9л ВолжМСК          Молоко 3,2% 0,9л ВолжМСК
# Сосиски Деревенские с сыром в/с         Сосиски Деревенские с сыром в/с
# Булочка бутербродная 5*60г         Булочка бутербродная 5*60г
# Какао бол         Какао бол
# Капучино мал         Капучино мал
# 460Г СТЕЙК ТОП БЛЕЙД ГОВ. ОХЛ.         460Г СТЕЙК ТОП БЛЕЙД ГОВ. ОХЛ.
# 500Г КОНФЕТЫ МИШКА КОСОЛАПЫЙ         500Г КОНФЕТЫ МИШКА КОСОЛАПЫЙ
# 600Г СГУЩ/МОЛОКО ГОСТ ПЭТ         600Г СГУЩ/МОЛОКО ГОСТ ПЭТ
# MPROF 250ШТ САЛФ БЕЛЫЕ 3СЛ 24Х24         MPROF 250ШТ САЛА БЕЛЫЕ 3С 24Х24
# КУС ГОВЯДИН 85Г ФЕЛИ         КУС ГОВЯДИНЫ 85Г ЦЕЛИ
# ЧЕРЕШНЯ КНОПКА 22         ЧЕРЕШНЯ КНОПКА 22
# ШОКОЛ.МОЛ.ЦЕЛ.ФУН90Г         ШКОЛ.МОЛ.ЦЕЛ.ФУН90Г
# Рассольник ленинградский 1 порц.         Рассольник ленинградский 1 пор.
# Сметана         Сметана
# Чай с лимоном 1 порц.         Чай с лимоном 1 пор.
# ВОДА ЛЕЧ-СТ.БОРЖ 075         ВОДА ЛЕТ-СТ.БОРТ 075
# ЙОГ ЧЕРН 1,5% 750Г         ЙОГ ЧЕРН 1,5% 750Г
# Рез жев Орбит Освежающий цитрус 14г Ригли         Рез жев Орбит Освежающий цитрус 14г Ригли
# Набор для окрошки с колбасой         Набор для окрошки с колбасой
# Салат Сельдь под шубой         Салат Сельдь под шубой
# КОКА-КОЛА Б/САХ 0,33         КОКА-КОЛА Б/САХ 0,33
# КОЛБАСА ФАНТАЗИЯ С/К         КОЛБАСА ФАНТАЗИЯ С/К
#  Паш"ГранМэр"печ/кл150гр          Паш"ГранЯми"печ/кл150гр
#  Сосис"Хуторок"Хуторок"400гр          Сосис"Хуторок"Хуторок"400гр
#               СКРЕБКИ Д/ПОСУДЫ,9ШТ                       СКРЕБКИ Д/ПОСУДЫ,9ШТ
#          ВЛ.САЛФ.АНТИБАК.20ШТ                  ВЛ.САЛА.АНТИФА.20ШТ
#  К"Мясная"ПАПА МОЖЕТ!"500г          К"Мясная"ПАПА МОЖЕТ!"500г
#  ХЛЕБ I/II СОРТ 600Г ИРКУТСКИЙ ХЛЕБОЗАВОД          ХЛЕБ I/II СОРТ 600Г ИРКУТСКИЙ ХЛЕБОЗАВОД
# Лепешка Узбекская 330г Тандыр         Лепешка Узбекская 330г Тандыр
# Печень говяжья п/ф         Печень говяжья п/ф
# Лак д/ногтей с Кальцием Classics 11мл         Лак д/ногтей с Кальцием Classics 11мл
# 1ШТ OB З/Щ КОМП ПЯТИСТОР 40 СР         1ШТ OB З/Щ КОМП ПЯТИСТАХ 40 СР
# Вода газ Кока-Кола 1л пэт 1/12         Вода газ Кока-Кола 1л пэт 1/12
# ПЕРЧАТКИ "ЛАТЕКО"         ПЕРЧАТКИ "ЛАТЕКО"
# УКРОП ЛОТОК 50 ГРАММ         УКРОП ЛОТОК 50 ГРАММ
# ФРУКТЫ СВ. ГРУША ПЭКХЭМ 1КГ         ФРУКТЫ СВ. ГРУША БЕКХЭМ 1КГ
# Помидор красный КНР         Помидор красный КНР
# Чипсы Dr.KORNER кукурузно-рисо         Чипсы Dr.KORNER кукурузно-риск
# Гель Sanita Антиржавчина 500г СХЗ         Гель Sanita Антиржавчина 500г СЭЗ
# Икра кабачковая С&В 680г. СТМ Рус         Икра кабачковая С&В 680г. СТМ Рус
# Кофе  NESCAFE CLASSIK Стекло 47.5г         Кофе  NESCAFE CLASSIK Стекло 47.5г
# Пирожное Эклер с ванильной нач         Пирожное Эклер с ванильной нач
# W368-U  Носки Wilson 2PP Wilson Women No show rectangle р.M         W368-U  Носки Wilson 2PP Wilson Women No show rectangle р.M
#  К.Ц.Нап.КОЛА б/алк.2л          К.Ц.Нап.КОЛА б/алк.2л
# Салат-бар         Салат-бар
# окуметил капли гл. 10мл фл-кап.         отметил капли гл. 10мл фл-кап.
# ВодаПитьевая ArabaTskaya газ 1,5л         ВодаПитьевая ArabaTskaya газ 1,5л
# Вафли Ореховые вес 1 кг Тортугалия         Вафли Ореховые вес 1 кг Португалия
# КАПУСТА ЦВЕТНАЯ         КАПУСТА ЦВЕТНАЯ
# Сливочный суп с лососем         Сливочный суп с лососем
# Омлет с капустой брокколи,шт         Омлет с капустой брокколи,шт
# Тофу "С укропом и чесноком",шт         Тофу "С уклоном и чесноком",шт
# ТОМАТЫ СЛИВКА ОРАНЖ. КНОП.183         ТОМАТЫ СЛИВКИ ОРАНЖ. КНОП.183
# ТРК -  1    АИ-95-К5         ТРК -  1    АИ-95-К5
# КАРТОФЕЛЬ-ФРИ БОЛ.         КАРТОФЕЛЬ-ФРИ БОЛ.
# Вода минеральная Эвиан негазир         Вода минеральная Эван негатив
# Каша рисовая на кокосовом моло         Каша рисовал на кокосовом моло
# Огурцы Эстафета         Огурцы Эстафета
# Салат Купеческий 1кг (СП)         Салат Купеческий 1кг (СП)
# ПФ ШЕЙНАЯ ЧАСТЬ СВИНАЯ БЕЗ КОСТИ         ПФ ШЕЙНА ЧАСТЬ СВИНАЯ БЕЗ КОСТИ
# Вода Монастырская детская н/газ 0,33         Вода Монастырская детская н/газ 0,33
# ГОЛЕНЬ ЦБ ОХЛ, КД         ГОЛЕНЬ ЦБ ОХЛ, КД
# СМЕТАНА 15% 315Г БРЕ         СМЕТАНА 15% 315Г БРЕ
# Кофе Гранд-латте 400мл         Кофе Гранд-латте 400мл
# Свободная продажа         Свободная продажа
# Напиток газированный Schweppes         Напиток газированный Schweppes
# Хлеб Био ржаной Strock Brot Gm         Хлеб Био ржаной Strock Brot Gm
# Ягодный микс (голубика,клубник         Ягодный микс (голубика,клубни
# MPROF 250ШТ САЛФ БЕЛЫЕ 2СЛ 24Х24         MPROF 250ШТ САЛА БЕЛЫЕ 2С 24Х24
# Комбо с Чизбургером 2 порц.         Комбо с Чизбургером 2 пор.
# Тирамису         Тиражами
# ХВС(содерж-е ОИ)         ВВС(содерж-е ОИ)
# Морковь Хабаровск         Морковь Хабаровск
# КОЛБАСА КРОВЯНАЯ ДЛЯ ЖАРКИ ДОМАШНЯЯ АГРОТЕК 1КГ         КОЛБАСА КРОВЯНАЯ ДЛЯ ЖАРКИ ДОМАШНЯЯ ГРАМОТЕ 1КГ
# 6 шт Куриные крылышки         6 шт Куриные крылышки
# ГРУППА ТОВАРОВ  1         ГРУППА ТОВАРОВ  1
#  ТЕНД.Туш.цып.бр.1с охл.фас.1кг          ТЕНИ.Туш.вып.бр.1с охл.фас.1кг
# Коньяк ДЕРБЕНТ 3 года 40% ст/б 0.5л         Коньяк ДЕРБЕНТ 3 года 40% ст/б 0.5л
# Фарш натуральный рубленный из мяса цыпленка охл 1кг         Фарш натуральный рубленный из мяса цыпленка охл 1кг
# Котлеты куриные         Котлеты куриные
# Французский Хот-дог с колбаской Мадейра         Французский Хот-дог с колбаской Мадейра
# Вода Nestle Pure Life Газ 0.5л. МПК         Вода Nestle Pure Life Газ 0.5л. МПК
# 0,2 Нап. мол. Кофе Латте         0,2 Нап. мол. Кофе Латте
# ЛАТТЕ         ЛАТТЕ
# 3 соуса по цене 2-х: Соус деликатесный Терияки (промо)         3 соуса по цене 2-х: Соус деликатесный Терияки (промо)
# Купон 3844: Станд Картофель фри         Купон 3844: Стан Картофель фри
# БИГ МАК БЕКОН         БИГ МАК БЕКОН
# самса         сама
# КУПАТЫ ГРИЛЬ ОХЛ.400         КУПАТЫ ГРИЛЬ ОХЛ.400
# Мыло жид Весна Алоэ/Овсяное Молочко 280мл         Мыло жид Весна Алоэ/Овсяное Молочко 280мл
# ПЕРЕЦ ЖЕЛТЫЙ ВЕСОВОЙ         ПЕРЕЦ ЖЕЛТЫЙ ВЕСОВОЙ
# ТОМАТЫ БАНЧ ВЕС         ТОМАТЫ БАНК ВЕС
# Корм д/собак Педигри говядина 100г пауч         Корм д/собак Подвиги говядина 100г патч
# ШОКОЛАД АЛЬПЕН ГОЛЬД МАКСФАН ВЗРЫВНАЯ КАРАМЕЛЬ/ЯГОДЫ/РИС ШАРИКИ 160Г         ШОКОЛАД АЛЬПЕН ГОЛЬД МАКСИМА ВЗРЫВНАЯ КАРАМЕЛЬ/ЯГОДЫ/РИС ШАРИКИ 160Г
# Ср-во д/мытья полов Mr Proper 500мл Асс         Ср-во д/мытья полов Mr Proper 500мл Асс
# Филе из грудки куриной по-венециански 95         Филе из грудки куриной по-венецианский 95
# VEN Взятие крови из вены         VEN Взятие крови из вены
# Укроп 50г фас.Ч/Л Россия         Укроп 50г фас.Ч/Л Россия
# Хлеб Камский Халяль 350 г Челны-Хлеб         Хлеб Камский Халяль 350 г Челны-Хлеб
# Лопатка свин. б/к (мален.кусок) охл. в/у вес М         Лопатка свин. б/к (ален.кусок) охл. в/у вес М
# Леденец Груша,шт         Леденец Груша,шт
# Сыр "Российский",кг         Сыр "Российский",кг
# Шоколад Альпен Гольд молочный фундук 90г         Шоколад Альпен Гольд молочный фундук 90г
# ЛУК РЕПЧАТЫЙ ПЦ ВЕС         ЛУК РЕПЧАТЫЙ ПЦ ВЕС
# ЧЕСНОК МОЛОДОЙ ВЕС         ЧЕСНОК МОЛОДОЙ ВЕС
# черный хлеб бл         черный хлеб бл
# МОРКОВЬ ИМПОРТ         МОРКОВЬ ИМПОРТ
#  Оладьи из печени, вес          Оладьи из печени, вес
#  Плюшка "Сахарная", 150 г          Плюшка "Сахарная", 150 г
# Корм д/кошек Friskies подлив кур 85г пауч         Корм д/кошек Friskies подлив кур 85г патч
# Батончик БИОИННОВАЦИИ Кофе с шоколадом 25г         Батончик БИОИННОВАЦИИ Кофе с шоколадом 25г
# Хлеб Бородино 400г         Хлеб Бородино 400г
# Сетевой газ         Сетевой газ
# Варенье из малины без сахара,шт         Варенье из малины без сахара,шт
# Напиток газ Кока-кола 0.5л ПЭТ Россия, шт         Напиток газ Кока-кола 0.5л ПЭТ Россия, шт
# Яйцо кур стол. Отборное 10шт картон Окское Россия, шт         Яйцо кур стол. Отборное 10шт картон Окское Россия, шт
# Ветка новогодняя декоративная, 29см ИМП         Ветка новогодняя декоративная, 29см ИМП
# ...
# Филадельфия с угрем         Филадельфия с углем
# Мол Отб3.4%-6% 0,93л          Мол От3.4%-6% 0,93л
# !феррум лек таб жев. 100мг n30         !форума лек таб жев. 100мг n30
# Грудинка на кости свинина охл кг         Грудинка на кости свинина охл кг
# мыльница настольная открытая         мыльница настольная открытая
# МОЛОКО  СГУЩЕНКА С САХ  370ГР Ж/Б ГУСТИЯ         МОЛОКО  СГУЩЕНКА С САХ  370ГР Ж/Б ГУСТАЯ
# Шаурма с курицей 125г         Шаурма с курицей 125г
# Вода минерал ГРАФ СУВОРОВ 1,5л         Вода минерал ГРАФ СУВОРОВ 1,5л
# Сыр мягкий с белой плесенью "Делис",шт         Сыр мягкий с белой плесенью "Денис",шт
# БЗМЖ Сырок творожный Волжские просторы с ванилином 8% 100г         БЗМЖ Срок творожный Волжские просторы с ванилином 8% 100г
# Шоколад"Вдохновение" 100 г         Шоколад"Вдохновение" 100 г
# 0,7Л ЛИКЕР БЭЙЛИС СЛИВОЧН ОРИГ         0,7Л ЛИКЕР БЭЙЛИ СЛИВОЧН ОРИГ
# ATUM95(АИ-95-К5 N 6         ATUM95(АИ-95-К5 N 6
#  Мор.ФИЛ.ЛАКОМКА плом.шок.гл.90г          Мор.ФИЛ.ЛАКОМКА полом.шок.гл.90г
# доппельгерц актив от а до цинка таб         доппельгерц актив от а до цинка таб
# Виски кола         Виски кола
# Печ. Удача с корицей 1кг (2) Венеция         Печ. Удача с корицей 1кг (2) Венеция
# Лавашики Пшеничные 216г БКК         Плавники Пшеничные 216г БАК
# СКОБА САМОРЕЗОВ МАЛАЯ         СКОБА САМОЛЕТОВ МАЛАЯ
# КРЕКЕР С СЫРОМ 100Г         КРЕМЕР С СЫРОМ 100Г
# Пряники Полет Завар.400г мятные         Пряники Полет Захар.400г мясные
# БИБ 0,5         БИБ 0,5
# Нектар Любимый 0,2л яблоко т/п         Нектар Любимый 0,2л яблоко т/п
# Вода питьевая Аква Минерале не         Вода питьевая Аква Минералы не
# Магнит Мэйджик Лэнд 1шт         Магнит Мэджик Лэнд 1шт
# 2038-Z4 42  Шлепанцы JOY Unisex Slippers темно-синий р.42         2038-Z4 42  Шлепанцы JOY Unisex Slippers темно-синий р.42
# РАФ  напиток кофейный 250мл         РАФ  напиток кофейный 250мл
# ОТБЕЛИВАТЕЛЬ БЕЛИЗНА САЯНСКХИМПЛАСТ 1Л         ОТБЕЛИВАТЕЛЬ БЕЛИЗНА САЯНСКХИМПЛАСТ 1Л
# Хлеб столичный (ручная)         Хлеб столичный (ручная)
# Фарш из свинины охл.         Фарш из свинины охл.
# Морож. Большой папа 130г рожок клубника         Мороз. Большой папа 130г рожок клубника
# Морож. Большой папа 130г рожок шоколад         Мороз. Большой папа 130г рожок шоколад
# Кофе 3 в 1 200гр         Кофе 3 в 1 200гр
# Пиво Циндао Лаошань 0,5л ж/б 4,7%         Пиво Циндао Лаошань 0,5л ж/б 4,7%
# Подлив 75гр         Подлив 75гр
# - Барбекью         - Барбекью
# КУПОН 7070: Сандерс Баскет Дуэт ОРИГ         КУПОН 7070: Сандерс Банкет Дуэт ОРИГ
# Суп Рамен Том Ям с морепродуктами         Суп Рамен Том Ям с морепродуктами
# свеча интерьерная Spaas в стак         свеча интерьера Spaas в стак
# Хлеб ржаной с тыквенными семечками 350г         Хлеб ржаной с тыквенным семенами 350г
# * HEINZ Пюре НЕЖ.ГРУШКА дет.100г         * HEINZ Пюре НЕЖ.ГРУШКА дет.100г
# Масло подсол.раф. Урожайное 0,870л         Масло посол.раф. Урожайное 0,870л
# 10. ЯЙЦО С-1 ДУКЧА 1ДЕС         10. ЯЙЦО С-1 ДУКЧА 1ДЕС
# Шоссон ветчина, сыр ШАРЛОТКА 150г         Шоссон ветчина, сыр ШАРЛОТТА 150г
# Американо 150мл         Американо 150мл
# Бостон пшеничное 0,33         Бостон пшеничное 0,33
# Сушка Кроха ванильная 200г Семейка Озби         Сушка Кроха ванильная 200г Семейка Оби
# Шок батончик ПИКНИК 38г         Шок батончик ПИКНИК 38г
# Молоко Фермерское подворье 3,5% 1л ЭДЖ         Молоко Фермерское подворье 3,5% 1л ЭДЖ
# гематоша таб жев. n10 со вкусом вишн         гематоша таб жев. n10 со вкусом вин
# Сухарики пшеничные,шт         Сухарики пшеничные,шт
# Круассаны Яшкино мини 180г слив.крем (8) ЯК101         Расписаны Яшкино мини 180г слив.крем (8) ЯК101
# Пельмени Цезарь 900г сибирские (8) Морозко         Пельмени Цезарь 900г сибирские (8) Морозко
# Лифт (техосвидетельствование) (пени)         Лифт (техосвидетельствование) (пени)
# Молодой картофель жареный с грибам         Молодой картофель жареный с грибам
# Самса с куриным фаршем         Самца с куриным фаршем
# Творог Серышевский обезжиренный 280г (не назначена) шт         Творог Серышевский обезжиренный 280г (не назначена) шт
# Нагрев.табачн.палочки (стики) Парламент ярко зеленый         Нагрев.табачн.палочки (стики) Парламент ярко зеленый
# Обувь         Обувь
# Печенье ЧокоПай Virosco original М/у 108г         Печенье ОкопАх Virosco original М/у 108г
# Сырники 1шт         Сборник 1шт
# Холодный чай Fuze Tea зеленый манго-рома         Холодный чай Fuze Tea зеленый манго-рома
# Мак изд Шебекенские № перо рефл 450г         Мак изд Шебекенские № перо реал 450г
# ФАРШ КУРИНЫЙ         ФАРШ КУРИНЫЙ
# Пряник Молодежный         Пряник Молодежный
# D405MM-. Стельки Solers Insoles р.41-45         D405MM-. Стельки Solers Insoles р.41-45
# Ессентуки № 4 0,45ст ТЭСТИ         Ессентуки № 4 0,45ст ТЭСТИ
# КОЛБАСКИ ПО-ГРЕЧЕСКИ         КОЛБАСКИ ПО-ГРЕЧЕСКИ
# Рис с овощами 200г         Рис с овощами 200г
# Чедар плав. сырный продукт с зам.мол.жира 50% 90г Владивосток         Чедар плав. сырный продукт с зам.мол.жира 50% 90г Владивосток
# ТОМАТЫ ЧЕРРИ СЛИВ.САНРАЙЗ 250Г         ТОМАТЫ ЧЕРРИ СЛИВ.САНРАЙЗ 250Г
# Хурма Королек 1кг Казахстан         Хурма Королей 1кг Казахстан
# Картофель фри средняя 1 порц.         Картофель фри средняя 1 пор.
# Чай фруктовый 400мл         Чай фруктовый 400мл
# Соус Чесночный 40г         Соус Чесночный 40г
# Масло подсолнечное Золотая семечка РД 1л (018) 1*15 (Новый) Новый         Масло подсолнечное Золотая семечка РД 1л (018) 1*15 (Новый) Новый
#  F.H.Салат ВИТАМ.мор.кап.470г          F.H.Салат ВИДАМ.мор.кап.470г
# Шляпа         Шляпа
# ПЕРЧАТКИ МЕД  S  N10         ПЕРЧАТКИ МЕД  S  N10
# КОНТЕЙНЕР 1Л         КОНТЕЙНЕР 1Л
# ГУРМЭ ПЕРЛ ИНДЕЙКА85         ГУРМЭ ПЕРЛ ИНДЕЙКА85
# СУХАРИКИ КИРИЕШКИ СОЛЕНЫЕ ВКУС КРАСНОЙ ИКРЫ 40Г         СУХАРИКИ КИРИЕНКО СОЛЕНЫЕ ВКУС КРАСНОЙ ИКРЫ 40Г
# Шеф-салат с ростбифом         Шеф-салат с ростиком
# 1Л ГАЗ.НАП.ПЕПСИ КОЛА         1Л ГАЗ.НАП.ПЕПСИ КОЛА
# СЛОЙКА С КУРИЦЕЙ 90Г         СЛОЙКИ С КУРИЦЕЙ 90Г
# Кофе Капучино 0,3         Кофе Капучино 0,3
# гриппофлю порошок д/приг.р-ра 13г n10 мали         гриппофлю порошок д/при.р-ра 13г n10 мали
# Шаньга с картошкой         Шаньга с картошкой
# Карандаш WORKMATE шестигр.с ластиком (зеленый)         Карандаш WORKMATE шести.с ластиком (зеленый)
# Брауншвейгская с/к в/с Губкинский мяс.ком.         Брауншвейгская с/к в/с Губкинский мчс.ком.
# ЛАПША БЫСТР.ПРИГ.75Г         ЛАПША БЫСТР.ПРИ.75Г
# Фонарь налобный, бат.3*АА не в комп ИМП         Фонарь налобный, бат.3*А не в комп ИМП
# Напиток б/а Фанта Апельсин 1л пэт         Напиток б/а Фанта Апельсин 1л пэт
# РК ф Инстинктив 85 г пауч в соусе         РК ф Инстинктив 85 г паук в соусе
# * АКТ.Биойог.черн./зл/с.льна150г         * АКТ.Биолог.черн./за/с.льна150г
# Имбирь 1 порц.         Имбирь 1 пор.
# КРАБ. ПАЛОЧКИ         КРАБ. ПАЛОЧКИ
# Колбаса Елецкая вареная 600 г Челны-Бройлер         Колбаса Немецкая вареная 600 г Челны-Бройлер
# Пиво Бад 5,0% ст/б 0,47 л         Пиво Бад 5,0% ст/б 0,47 л
# WD 40 ТЕХНИЧ.СПРЕЙ         WD 40 ТЕХНИЧ.СПРЕЙ
# SMSMU0002_1-AZ 39-42  Носки для спорта (3 пары) Sport socks (3 pairs) черный/синий/серый р.39-42         SMSMU0002_1-AZ 39-42  Носки для спорта (3 пары) Sport socks (3 pairs) черный/синий/серый р.39-42
# Котлеты Новоарбатские жареные         Котлеты Новоарбатские жареные
# Батон нарезной 400гр         Батон нарезной 400гр
# Соус сырный 2 шт.         Соус сырный 2 шт.
# Сидр грушевый         Сидр грушевый
#  Мол.ул"БожКор"3,2%900/950млТБА          Мол.ул"БожКор"3,2%900/950маРТА
#  Яйцо курС2 фас 10шт бокс Город          Яйцо курС2 фас 10шт бокс Город
# НАР.КОЛБ.ДОКТ.190Г         НАР.КОЛБ.ДОКТ.190Г
# 70Г ЧИПСЫ МК СОЛЬ         70Г ЧИПСЫ МК СОЛЬ
# Кукуруза Лорадо 425мл сладкая ж/б         Кукуруза Лорадо 425мл сладкая ж/б
#  Газ.нап"Пепси"0,5л          Газ.нап"Пепси"0,5л
# Тарелки одноразовые Лимон 24 с         Тарелки одноразовые Лимон 24 с
# Чай TESS Flirt зеленый аром пе         Чай TESS Flirt зеленый даром пе
# Губка бытовая с чистящим слоем 10 шт         Губка бытовая с чистящим слоем 10 шт
# КРУПА ПМЖЛ ПЕРЛОВАЯ ЯЧМЕННАЯ НОМЕР ПЕРВЫЙ 800Г         КРУПА ПМЖЛ ПЕРЛОВАЯ КАМЕННАЯ НОМЕР ПЕРВЫЙ 800Г
# Тайский салат с баклажанами         Тайский салат с баклажанами
# * 48 КОП.Мор.ПЛОМБ.мал.в.в/ст.91г         * 48 КОП.Мор.ПЛОМБ.мал.в.в/ст.91г
# КД/ЧЕСНОК 10ГР         КД/ЧЕСНОК 10ГР
# Облепиховое масло супп рект 500мг №10         Облепиховое масло суп реки 500мг №10
# Пирожок с яблоками 90гр         Пирожок с яблоками 90гр
# стм семя льна 100г         стм семя льна 100г
#  П.в"Кубай"н/газ 1,5 л          П.в"Дубай"н/газ 1,5 л
#  Булка"Славянка"твор.2шт*50гВХК          Булка"Славянка"твор.2шт*50гВХК
# ПЫЛЬНИК ПРИВОДА ВНУТРЕННИЙ         ПЫЛЬНИК ПРИВОДА ВНУТРЕННИЙ
# ВОДА АРХЫЗ 1,5Л         ВОДА АРХЫЗ 1,5Л
#  LEN.Карамель ТРОСТЬ Асс.лед.28г          LEN.Карамель ТРОСТЬ Асс.лед.28г
# EPRI/КАРАНДАШ Ч/Г 1         EPRI/КАРАНДАШ Ч/Г 1
# Буженина к/в Традиционная Скиф         Женщинам к/в Традиционная Скиф
# Корм д/собак Цезарь говяд/крол/шпинат 100г пауч         Корм д/собак Цезарь говд/крол/шпинат 100г патч
# Фунчоза         Фунчоза
# яйцо куриное С1 10 шт бокс ИП Мусиенко         яйцо куриное С1 10 шт бокс ИП Мусиенко
# Газета Аргументы недели         Газета Аргументы недели
# Сорочка верхняя трик. мужская         Сорока верхняя трик. мужская
# Огурцы свежие КНР    Кл 158         Огурцы свежие КНР    Кл 158
# Кофе с молоком зерно         Кофе с молоком зерно
# Морковь КНР 1кг кг         Морковь КНР 1кг кг
# * РОЛ.И/м ЛАП.С ГОВ.ПО-ДОМ.б/п90г         * РОЛ.И/м ЛАП.С ГОВ.ПО-ДОМ.б/в90г
# Сельдь т/о ф/к с аром/чеснока 210г Гранд Марин         Сельдь т/о ф/к с паром/чеснока 210г Гранд Марин
# Филе грудки индейки малое охл 500г лоток Индилайт         Филе грудки индейки малое охл 500г лоток Синдикат
# Депозит         Депозит
# Слойка Булочка с изюмом         Стойка Булочка с изюмом
# Колесо для пятилучия(шт)         Колесо для пятилучия(шт)
#          ГЕЛЬ Д/ДУША BELLE CO                  ГЕЛЬ Д/ДУША BELLE CO
# Салат с ветчин.и сыр.в блине         Салат с ветчин.и сыр.в длине
# Пиво Эдельвейс бут 0,45л         Пиво Эдельвейс бут 0,45л
# Корм д/кошек Kitekat мясной пир 1,9кг         Корм д/кошек Kitekat мясной пир 1,9кг
# Чай 200мл         Чай 200мл
# Сандерс Баскет новый: 2 шт ОСТР Стрипсы кур фил         Сандерс Банкет новый: 2 шт СТР Стрипсы кур фил
# ЖЕРЕХ ХК ПЛАСТ         ЖЕРЕХ ХК ПЛАСТ
# ШАМ 380МЛ ОТ ПЕРХ.ИН         ШАМ 380МЛ ОТ ПЕР.ИН
# 0001 ОДЕЖДА         0001 ОДЕЖДА
# A19ADMGLU03-99 L  Перчатки Gloves чёрный р.L         A19ADMGLU03-99 L  Перчатки Gloves чёрный р.L
# W838-W Носки для спорта (2 пары) Wilson 2PP Wilson Low cut Needle out design р.S         W838-W Носки для спорта (2 пары) Wilson 2PP Wilson Low cut Needle out design р.S
# Яблоко декоста         Яблоко декоста
# Пирожок с картошкой и грибами 100г         Пирожок с картошкой и грибами 100г
# Масло КОРОНА  5л*3шт шт         Масло КОРОНА  5л*3шт шт
# 308УРО Mycoplasma genitaliu...         308УРО Mycoplasma genitaliu...
# Сардина т/о Иваси 500г ж/б РЗБ         Сардина т/о Васи 500г ж/б РУБ
# Уксус яблочный 6% ст/б 0,5л         Уксус яблочный 6% ст/б 0,5л
# котлета в тесте         котлета в тесте
# Мороженое Сливочное с шоколадом,шт         Мороженое Сливочное с шоколадом,шт
# ДОЖДИК В АССОРТИМ         ДОЖДИК В АССОРТИМ
# МАКАРОН РОЖКИ БОЛЬШИ         МАКАРОН РОЖКИ БОЛЬШЕ
# Гуляш из свинины 50/50г, 274ккал         Гуляш из свинины 50/50г, 274ккал
# ЙОГ ПИТ ЧЕРЕШНЯ 0.4%         ЙОГ ПИТ ЧЕРЕШНЯ 0.4%
# Майка мужская         Майка мужская
# Пирожное "Булочка ШУ"         Пирожное "Булочка ШУ"
# Салаты 70         Салаты 70
# Царская L         Царская L
# 185Г МИДИИ КОП.Д/М КАП.ВКУ         185Г МИДИИ КОП.Д/М КАП.ВКУ
# Саморезы д/крепл.ГКЛ к дер.3,5х51 50шт. упак         Самолеты д/крепл.ГОЛ к дер.3,5х51 50шт. упак
# Булочка со сгущенным молоком 0,2кг Пекарня-ВЛ         Булочка со сгущённым молоком 0,2кг Пекарня-ВЛ
# Термобокс 1 шт.         Термобокс 1 шт.
#          ДРАЖЕ M&M'S С АРАХИС                  ДРАЖЕ M&M'S С АРАХИС
# 1/1 Пластырь бактерицидный Унипласт влагостойкий 2,5х7,2см  (плен)         1/1 Пластырь бактерицидный Унипласт влагостойкий 2,5х7,2см  (плен)
# Арахис в глазури Новый Восток краб 100г         Арахис в глазури Новый Восток краб 100г
# ТестоСдобноеДрожжевое1кг         ТестоСдобноеДрожжевое1кг
# Молокосодержащий продукт Снеговичок 90 гр СЗМЖ         Молокосодержащий продукт Снеговичок 90 гр СЗМЖ
# Хлеб Пшеничный в/с 600г Нарышкино         Хлеб Пшеничный в/с 600г Нарышкино
# Коктейль молочн  паст 2,5% 0,5л банан Хороль         Коктейль молочно  паст 2,5% 0,5л банан Хороль
# Скумбрия соленая кусочки в/у, 300 г,шт         Скумбрия соленая кусочки в/у, 300 г,шт
# Ф Бун Том         Ф Бун Том
# ВАФЛИ ПМЖЛ С ВАРЕНОЙ СГУЩЕНКОЙ 200Г         ВАФЛИ ПМЖЛ С ЖАРЕНОЙ СГУЩЕНКОЙ 200Г
# 2.ЛИНКОМИЦИНА Г/Х 0.25 №20 КАПС.(УПАК)         2.ЛИНКОМИЦИНА Г/Х 0.25 №20 КАСС.(УПАК)
# Клубничный Лимонад 0,32 л.         Клубничный Лимонад 0,32 л.
# Облепиховый чай 1 порц.         Облепиховый чай 1 пор.
# Картофель жаренный с зеленью и чесноком         Картофель жареный с зеленью и чесноком
# Кондиционер ЭТО Детский 1л         Кондиционер ЭТО Детский 1л
# Перчатки садовые ХБ черные 10кл 80г точка двойные         Перчатки садовые ХБ черные 10кл 80г точка двойные
# Батон Новый 380 гр б/п         Батон Новый 380 гр б/п
# Кукуруза сахарная в зернах,шт         Кукуруза сахарная в зернах,шт
# Имбирь свежий 300г лоток, шт         Имбирь свежий 300г лоток, шт
# PROХВОСТ Д/КОШ  КРОЛ         PROХВОСТ Д/КОШ  КРОЛ
#  Салат Сельдь под шубой          Салат Сельдь под шубой
# Гарнир 0,5 (20)         Гарнир 0,5 (20)
# компот 35         компот 35
# Гуляш свинина         Гуляш свинина
# КОФЕ NESCAFE GOLD85Г         КОФЕ NESCAFE GOLD85Г
# МЕДОВУХА ЧЕСТЕР САЙДЕР ВИШНЕВЫЙ ГАЗ 5,5% 0,5Л         МЕДОВУХА ЧЕСТЕР РАЙДЕР ВИШНЕВЫЙ ГАЗ 5,5% 0,5Л
# 500Г ДОКТОРСКАЯ ГУБЕРНСКАЯ В СЕТК ЧЕРК         500Г ДОКТОРСКАЯ ГУБЕРНСКАЯ В СЕТИ ЧЕРК
# Игрушка "Пазл 3D" ИМП         Игрушка "Пазл 3D" ИМП
# Набор кухонных ковриков, 45*29см,2шт ИМП         Набор кухонных ковриков, 45*29см,2шт ИМП
# Лепешка Назуки с изюмом 400г Хлеб и Тандыр         Лепешка Науки с изюмом 400г Хлеб и Тандыр
# 1.  Коврик влаговпитывающий Ребристый   40*60см,коричневый Sunstep 1шт         1.  Коврик влаговпитывающий Ребристый   40*60см,коричневый Sunstep 1шт
# Бокс         Бокс
# спецблюдо160         спецблюдо160
# Конфеты МАСКА вес         Конфеты МАСКА вес
# Перец с рисом и мясом, шт         Перец с рисом и мясом, шт
# Эспрессо 1 порц.         Эспрессо 1 пор.
# Ежед.прокладки КОТЕХ 60 шт         Ежед.прокладки КОТЕЛ 60 шт
# !ксимелин капли назал. 0.1% 10мл фл-кап.         !кимберли капли начал. 0.1% 10мл фл-кап.
# ВОРОНЦ.СУХАРИКИ         ВОРОНА.СУХАРИКИ
# Ж.Р.Оrbit 13.6г         Ж.Р.Оrbit 13.6г
# Купон 3853: Адреналин Раш         Купон 3853: Адреналин Раш
# ЯЙЦО ШОК КИНДЕР СЮРПРИЗ НОВЫЙ ГОД ФЕРРЕРО 20Г         ЯЙЦО ШОК КИНДЕР СЮРПРИЗ НОВЫЙ ГОД ФЕРРЕРО 20Г
# Сэндвич с куриной грудкой         Сэндвич с куриной грудкой
# Печенье Ленинградское Сладкая Слобода затяжное м/у 350 г         Печенье Ленинградское Сладкая Слобода затяжное м/у 350 г
# ДТ N10:         ДТ N10:
# ингалипт аэрозоль 30мл фл алтайвитамины         финалист аэрозоль 30мл фл алтайвитамины
# Общий (клинический) анализ крови развернутый         Общий (клинический) анализ крови развернуты
# Пончик со вкусом банана 58гр         Пончик со вкусом банана 58гр
# Нектар ФРУКТОВЫЙ САД яблоко-ви         Нектар ФРУКТОВЫЙ САД яблоко-ви
# 30ШТ ЯЙЦО СТОЛОВОЕ СО Т.У.П.         30ШТ ЯЙЦО СТОЛОВОЙ СО Т.У.П.
# Молоко ТОМСКОЕ МОЛОКО пастер 3.4-6% пэт 900мл         Молоко ТОМСКОЕ МОЛОКО мастер 3.4-6% пэт 900мл
# Клаб сэндвич         Клаб сэндвич
# СЫР СО ВК.ТОМАТА 23Г         СЫР СО ВК.ТОМАСА 23Г
# Хлеб белый,серый (кусочек)         Хлеб белый,серый (кусочек)
# Пицца с ветчиной и грибами         Пицца с ветчиной и грибами
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-5b81ae56170c> in <module>
#       1 opechat2 = {}
#       2 for i in un_values:
# ----> 3     opechat2[i] = corrector.FixFragment(i)
#       4     print(i, '       ', opechat2[i])
#
# ~/IHaskell/diploma-paper/03. conference (17.04.21)/conference/lib/python3.8/site-packages/jamspell.py in FixFragment(self, text)
#     412
#     413     def FixFragment(self, text):
# --> 414         return _jamspell.TSpellCorrector_FixFragment(self, text)
#     415
#     416     def FixFragmentNormalized(self, text):
#
# KeyboardInterrupt:

# %%
import jamspell

# %%
corrector = jamspell.TSpellCorrector()

# %%
corrector = jamspell.TSpellCorrector()
corrector.LoadLangModel('ru_small.bin')
# Out:
# True

# %%
corrector.GetCandidates(['я', 'русский', 'человк', 'по', 'происхождению'], 1)
# Out:
# ('русский',
#  'русской',
#  'русских',
#  'русские',
#  'русским',
#  'русски',
#  'прусский',
#  'румский',
#  'рузский')

# %%
corrector.FixFragment('я просто невероянт зочу спыть')
# Out:
# 'я просто невероятно хочу спать'

# %% [markdown]
# ## I. Предобработка текста - внимание к мелочам

# %% [markdown]
# Стоит понимать, что при работе с чеками мы работаем не с обычным текстом, а с ужасно зашумлённым и непредобработанным. Поюсню это на основных моментах, которые учитывались при предобработке текста:
#
# 1. Достаём слова из текста
#
# Опишем возможные ситуации, которые встречаются в тексте.
#
# - неразделенные слова, например: `КормДляКошек` (*корм для кошек*) или `презервативыdurex` (*презервативы durex*)
# - неразделенные слова, но с опечатками/сокращениями внутри, например: `кормдкошек` (*корм для кошек*) - необходимо построить алгоритм поиска опечаток в словах
# - кстати про опечатки, они могут быть и в одиночных словах, так что это тоже стоит учитывать
# - всевозможные сокращения одного и того же слова, например, слово шампунь в чеках сокращалось 6-ую различными способами:
# `ш-нь, ш/нь, шамп., шампн., шампун., шмпнь` и это, наверное, не всё. Так же сокращения нужно применять тоже осторожно, полагаясь на контекст, потому что `шамп` может оказаться и *шампанским*. Таким образом необходимо построить алгоритм по сокращенному слову пытаться предсказывать его нормальную форму.
# - слова могут применяться по-разному в разных контекстах, например слово *краска* применялось в нескольких категориях - строительные материалы, рисование, цветы
# - английские слова часто могут быть подсказкой для определенной категории, поэтому их стоит хотя бы не выбрасывать: `например`, в `101` категории, представляющая из себя спортивное питание, было несколько компаний, которые связаны только со спортивным питанием
# - стоит отметить, что кажущиеся бессмысленными некоторые слова могут являться *аббревиатурой*, из которой можно много понять о категории чека. Например, в `92` категории есть очень много таких слов, например `хвс`: `холодное водоснабжение`, `жбо` - жидко бытовые отходы;
# - еще важно при парсинге слов искать различные сокращения вида `<буква>/<буква>`, для примера `б/а` - *безалкогольный*, а `х/к` - холодное копчение и.т.д - таких слов очень много и их тоже надо пытаться как-то понимать.
# - для трудно разделимых категорий можно попытаться понять общий смысл у слов в этой категории и попытаться добавить ключевое слово к каждому встречающемуся. Так, например, `90` категория была представлена очень малым количеством уникальных чеков, однако из слов `выходной, боулинг, бенгальский, батут, дискотека` можно было понять, что речь идет о каком-то отдыхе или празднике и добавить в список слов `праздник`, `удовольствие`, что позволяет лучше разделять классы между собой
#
# - при парсинге в лоб легко упустить какие-то мелочи: так, например в `7` и `9` категориях были представлены лишь какие-то двухбуквенные слова в перемешку с цифрами, по типу `АИ-92-k5` и при обработке текста в данной строке не найдется ничего полезного. Однако информации здесь очень много: данная абревиатура свойственна заправочным станциям, которые продают (евро) топливо на газовых голоках. Такие ситуации можно решать с помощью `regex` шаблонов:
#
# >  ```python
# import re
# s = "[аи|а|a|aи]{1,}[- ][0-9]{2,}[\w\/]{1,}[- ][0-9]{2,}[- ]\w\d|
#     [\w\/]{1,}[- ][0-9]{2,}-\w\d|
#     [аи|а|a|aи]{1,}[-+ | 0-9]{2,}[0-9a-zа-я]{2,}|
#     [аи|а|a|aи]{1,}[0-9]{2,}-\w\d|[аи|а|a|aи]{1,}[0-9-]{2,}|
#     трк|бензин|"
# words = re.findall(r'{}'.format(s), z)```
#
# - некоторые слова сокращаются до одной буквы - это было очень неприятно.
#
# В итоге данные идеи могли помочь в предобработке текста и могут быть взяты на вооржуение в будущем. Задача расстановки пробелов или исправления опечаток в зашумлённых текстах - интересная и важная задача.
#
# 2. Знаки препинания
#
#     - в чеках в этом плане творилась полная неразбериха. Слова могли сокращаться таким образом `стекл.очист. 200мл.д/т` и приходилось использовать какие-то хитрые сплиты - создавать шаблоны для сокращений `<word>/<word>`, проверять не сокращённое ли слово и.т.д
#     - иногда было важно то, что стоит в кавычках `"<word>"` или скобках `"(word)"`, это тоже стоит учитывать
#
# 3. Цифры
#
#     - с цифрами у меня был диалог короткий - я выуживал лишь наиболее встречающиеся конструкции, такие как `\d+л|мл|ml` или та же самая конструкция, но с килограммами, милиграммами и их сокращениями
#
#
# В итоге собирался словарь сокращений и писалась по ходу огромная и очень коряво-написанная функция для преобразования текста с огромным количеством `regex` выражений и условий. Но главное было не в реализации, а в идеях - что можно выжать из текста. Для любителей кода я в конце ноутбука помещу его, но я заранее извиняюсь :)
#
# Примеры предобработки текста:
#
#
#     - INPUT: Спинки варено-копченые из мяса ЦБ в/у охладенные
#
#     - OUPTUT: спинки варено копченые из мяса цыпленок бройлер вакуумная упаковка охладенные

# %% [markdown]
# ## II. Классы товаров
#
# Каждый класс товара я просматривал отдельно для каждой категории, находя какие-то смысловые общие нагрузки или заменяя опечатки, которые нельзя заменить программно. Таким образом, спустя несколько дней обработки, я получил следующую таблицу категорий.

# %% [markdown]
# - `0` - алкогольная продукция
# - `1` - презерватиры
# - `2` - сигареты
# - `3` - стики, нагреваемые табачные палочки
# - `4` - автомобильная лампа
# - `6` - различные приборы чистки для авто: щётки, стеклоочистители
# - `7` - газовые колонки, топливо, заправка
# - `9` - дизельное топливо
# - `11` - щётка, услуги автомойки
# - `12` - масла, смазки, ароматизаторы, антифризы для автомобилей
# - `13` - ремонт машин
# - `19` - канцелярские принадлежности, бумага
# - `20` - газеты, журналы
# - `24` - детская литература, книжки для малышки
# - `26` - органайзеры, ножницы, листки, закладки, корректоры
# - `27` - обложки, вкладыши, папки
# - `29` - карандаши, ручки
# - `30` - тетради, дошкольные предметы, прописи
# - `31` - все для художников
# - `35` - эфирные масла и свечи
# - `36` - витамины, гематогены, капсулы
# - `37` - детские: подгузники, мыло детское, шампуни
# - `38` - таблетки
# - `39` - контактные линзы
# - `40` - туалетная бумага, зубная щетка, паста, тампоны
# - `41` - тональные крема, тушь, помада
# - `42` - лак для ногтей, маникюр, гель
# - `43` - тесты на беременность, шприцы, бахилы, бинты, катетеры
# - `45` - врач: узи, кт, зубной
# - `46` - парфюмерия, косметика, туалетная вода:
# - `49` - все для волос: шампуни, расчесчки.
# - `50` - различные маски, крема: для лица
# - `51` - мыла, масла, дезодорант: для тела
# - `52` - шапки, варежки, ремни...
# - `53` - просто брюки
# - `54` - куртки, плащи, фуфайки..
# - `55` - только джинсы
# - `56` - брюки, сорочки, шорты
# - `57` - обувь: туфли, ботинки, сандали, тапочки
# - `58` - платье + сарафан
# - `60` - толстовки, джемперы, кардиганы, кофты
# - `61` - колготки, майки, куча одежды
# - `62` - спортивная одежда, шорты, треники, перекрывается...
# - `66` - пицца
# - `67` - роллы, суши..
# - `68` - бургеры, сэндвичи, бутреброды..
# - `69` - байтсы, куриные ножки, чикенбургеры - видимо, курица и.т.д.
# - `70` - кофе их разновидности, чай, какао
# - `71` - рестораны продукты: можно парсить названия по составу продуктов: всевозможные продукты!!
# - `72` - детское питание: фруто няня, соки для детей, пюрешки
# - `73` - замороженная продукция: рыба, замороженное мясо, тесто, пельмени
# - `74` - колбаса, свинина, сервелаты
# - `75` - консервно баночная продукция: ананасы в банках, шпроты, соленья
# - `76` - крупы: макароны, греча, каши
# - `77` - соусы, кетчупы, масло подсолнечное
# - `78` - молочные продукты: сыр, молоко, творог и.т.д
# - `79` - вот тут уже мясо: шницели, языки, курица, стейки
# - `80` - овощи и фрукты
# - `81` - орехи, чипсы, сухарики, гренки, арахис + кукуруза, горошек
# - `82` - рыбы... очень много различной рыбы
# - `83` - напитки, соки
# - `84` - наиболее представительная категория - сладости, ватрушки, хлебобулочные изделия, шоколадки: очень много
# - `85` - чаи кофе - видимо, нужно смотреть на цену, потому что будет очень много пересечений с категорией `70` - абсолютно идентичные. Видимо, данная категория: *кофе в магазине*, а `70` - в *ресторанах*.
# - `90` - праздничные товары, веселье, хлопушки, различные удовольствия
# - `92` - `ЖКХ` услуги
# - `96` - мячи насосы
# - `97` - бассейн, билеты в бассейн, маски продажа, очки для плавания, прокат катамаранов, добавил данные
# - `100` - наколенники, шлема - защитные устройства для спорта
# - `101` - протеиновые батончики, набор массы, смеси
# - `102` - спортивное оборудование: `штанги, гантели`. добавил материалы
# - `103` - все для рыбалки, походов, палатки,
# - `105` - различные трубы, Отводки, муфты, прокладки, связанные с водой
# - `106` - дверные замки, петли, застежки дверей
# - `107` - плоскогупцы, шпатели, отвертки, напильники, малярные инструменты,  лобзики: строительные красящие
# - `108` - аэрозоли, растворители, анисептикик - смеси
# - `109` - гайки, болты, гвозди
# - `111` - сантехника водные:  фильтры для раковин и.т.д
# - `114` - суперклеи, изолента, наждачная бумага, герметик, изоляция, клеи, клейкая лента, рубероид
# - `115` - тройники, розетки, провода, предохранители, кабеля, выключатели: все, что связано с электричеством
# - `117` - освежители, перчатки, стирательные порошки, мыло, пятновывадительные: со стиркой связанные
# - `118` - фоторамки, украшения, шары, горшки, свечи - всякие нужные материалы для дома
# - `120` - игрушки для детей: `лего`, машинки, конструкторы и.т.д
# - `121` - пакет (это не категория, просто единственное слово в этой категории)
# - `128` - прожектора, светильники, лампы, светодиоды: все, что со светом связано
# - `130` - банки, бутылки, декоративные контейнеры, кружки, стаканчики, крышки, миски, прихватки, салатницы, тарелки: `столовые приборы`
# - `133` - полотенца, простыни, скатерти, салфетки, подушки, одеяла, наволочки - хлопчато-бумажные
# - `138` - уголь, шампуры, решетки, сетка, щепа, черенки, лопаты, жидкость для розжига
# - `139` - мешки для мусора, зажигалки, мешки полиэтиленовые, перчатки - все для уборки + зажигалки(
# - `140` - цветы (для посадки), семена цветов, грунт для земли
# - `143` - пакет (это не категория, просто единственное слово в этой категории)
# - `145` - корм для кошек
# - `150` - корм для собак
# - `163` - рисование, раскраски
# - `164` - пластилин, тесто для лепки, глина
# - `167` - все для вышивания, нитки, ленты, бусины, крючки, стразы, ткань
# - `177` - для телефона: батарейки, держатели для телефона, чехлы для телефона, штекеры, электронное питание телефона, кабель для телефона lighting usb
# - `203` - все, что связано с упаковкой товара, коробки, конверты, упаковочаня бумага, одноразовые упаковки, пакеты упаковочные
# - `204` - какие-то услуги, посещения, услуги, гости, акции, но такое ощущение, что это категория для неопределимого.

# %% [markdown]
# Да, тут собрано буквально всё, что есть в мире. Весьма различимы несколько кластеров - еда, продукты, одежда, товары для дома, декоративные товары, развлечения. Каждая подгруппа также делится по смыслу на категории, однако встречаются и наложения, которые тяжело отметить даже специалисту - например `204` категория собрала в себя всевозможные услуги, посещения, праздники, встречалась и еда и её было тяжело отделять, как тяжело отделять кофейную продукцию в ресторанах от кофейной продукции в магазинах (категории `70` и `85`). По результатам отмечу следующие наблюдения:
#
# - все категории, в которых было большое количество уникальных чеков (больше 1000) (кроме `204`), отлично отделялись
# - были и категории с небольшим количеством наблюдений, но с отличной разделимостью благодаря большому количество одного повторящегося у всей категории слова - например `джинсы` или *прерзервативы*.
# - а вот категории с маленьким количеством уникальных чеков и без отличительной какой-нибудь черты (достаточно было одного повторяющегося слова) разделялись плохо - были предприняты даже попытки разметить и добавить в недостающие категории товары, но это стало непосильной задачей.

# %% [markdown]
# ## III. `Использованные модели`

# %% [markdown]
# В плане выбора модели я не блистал оригинальностью, перепробоав всевозможные типичные методы, но приведу те, которые мне понравились по идее и/или результату. Перед применением данных моделей производилась предварительная предобработка текста, описанная в пункте `I`:
#
# 1. (Идея)
#
#     - *TRAIN*: посчитать для каждой категории с помощью `Counter` из бибилотеки `collections` встречаемость каждого слова в определенной категории, создать словарь, в котором ключи - номер категории, а значения - словарь `counter` наиболее встречаемых слов в данном словаре (например, я брал `n=50`. Частоты нормируются и взвешиваются пропорциально встречаемости категории в тренировчном множестве
#
#     - *TEST*: предобработать аналогично тренировочному множеству тестовойе множество, посчитать вероятность принадлежности определенной категории через суммму весов - взять категорию с наибольшей суммой весов
#
# Иногда в соревнованиях выстреливали простые модели, но здесь результат был ужасным - лучший `0.6`.
#
# 2. (Идея) на предобработанных лемматезированных текстах я подумал, что можно обучить известную модель `Word2Vec`, только на всех `8` миллионах чеках уникальных чеках, а затем построить эмбеддинги предложений как среднее эмбеддингов и числа слов, которые есть из предложения в эмбеддинге. Получились даже вполне хорошие эмбеддинги (код я оставлю внизу, чтобы можно было их пощупать, есть разделимость по категориям, но результат разочаровал - `KNN CLassifier 9_neighbours` с метрикой `cosine` - лучший результат `0.77`.
#
# 3. (Результат) Предобработка текста + добавление цифр + получение прзнаков `TFIDF` со следующими параметрами:
#
# ```python
# tfidf = TfidfVectorizer(
#     max_features=800000,
#     ngram_range=(1, 6),
#     stop_words ='russian',
#     analyzer="char_wb",
#     norm = 'l2'
# )```
#
# Над всем этим используется линейный `SVMCLassifier` и получаем результат - `0.844`. Обидно, когда не придумал нового.
#
# 4. Были ещё и нейронные рекурретные сети, но лучше о них я рассказывать не буду...

# %% [markdown]
# ## IV. Выводы

# %% [markdown]
# Думаю, что по данному соревнованию я сделаю следующие выводы и наблюдения:
#
#     - предобработка текста очень важна и ею нужно заниматься (а ещё это очень прокачивает знание регулярных выражений)
#     - разметка малопредставленных категорий помогла бы улучшить качество модели
#     - в данной работе совершенно не использовалась информация о дне недели, цене, времени, поэтому хотелось бы в дальнейшем научиться строить модели, учитывая дополнительные признаки.
#
# Спасибо за соревнование, буду продолжать работать над идеями. А сейчас для дождавшихся - код :)

# %% [markdown]
# ## V Дополнительно: код

# %% [markdown]
# Код для предобработки.

# %% [markdown]
# !pip install pymorphy2

# %%
import pymorphy2
from functools import lru_cache
ru_lemmatizer = pymorphy2.MorphAnalyzer()
@lru_cache(maxsize=10 ** 6)
def lru_lemmatizer(word):
    '''лемматизация'''
    return ru_lemmatizer.parse(word)[0].normal_form

# %%
def prepare(train_data, perevod, lemir, maslin, prazdnik, do_lemma=False):
    '''
    INPUT
    
    ---------
    
    train_data :: pd.Dataframe - исходные данные, необходимо, чтобы был столбец item_name
    perevod :: словарь сокращений
    lemir :: список принадлежности замороженным продуктам
    maslin :: список принадлежности категории масляных банок и консервов
    prazdnik :: список слов, подразумевающих отдых или праздник
    do_lemma :: default=False, лемматизация слов в конце с помощью PyMorhy
    
    OUPTUT:
    
    vocab_large_dict :: словарь, ключи - уникальные значения train_data['item_name'], 
                                 значения - обработанная строка слов, слова отделены одиночным пробелом
                                 
    train_data :: новый DataFrame со столбцом preprocess
    
    '''
    un_values = train_data['item_name'].value_counts()
    print('STEP 1')
    a = []
    wd = {}
    for i in list(un_values.keys()):
        new = i.lower()
        splitted = re.findall(r'(\b[a-zA-Zа-яА-ЯеЁ_]+\b)', new)
        if splitted != []:
            if splitted[0] == new:
                if i.isupper():
                    #print(i)
                    wd[i] = {}
                    wd[i]['done'] = 'maybe'
                    wd[i]['word'] = i.lower()
                elif len(re.split("(?=[А-ЯA-Z\_])", i)) >= 2:
                    split = re.split("(?=[А-ЯA-Z\_])", i)[1:]
                    if any([x.lower() for x in split if len(x) == 1 and x not in string.punctuation]):
                        if ''.join(split[-3:]) == 'ИМП':
                            wd[i] = {}
                            wd[i]['done'] = 'yes'
                            wd[i]['word'] = ' '.join([x.lower() for x in split if len(x) !=1] + ['ИМП'])
                        else:
                            wd[i] = {}
                            wd[i]['done'] = 'no'
                            wd[i]['word'] = ' '.join([x.lower() for x in split if len(x) !=1])
                    else: 
                        wd[i] = {}
                        wd[i]['done'] = 'yes'
                        wd[i]['word'] = ' '.join([x.lower() for x in split if x not in string.punctuation])
                else:
                    a.append(i)
            else:
                a.append(i)
        else:
            a.append(i)
    print('STEP 2')
    b = []
    wd_2 = {}
    for i in a:
        text = re.sub(r'[{}]'.format(string.punctuation), ' ', i)
        splitted = re.findall(r'(\b[a-zA-Zа-яА-ЯеЁ_]+\b)', text)
        sub3 = re.sub(r'(\b[a-zA-Zа-яА-ЯеЁ_]+\b)', ' ', text)
        if ' '.join(splitted) == i:
            new_word = []
            for j in splitted:
                if j in perevod.keys():
                    new_word.append(perevod[j])
                elif j.isupper():
                    new_word.append(j.lower())
                elif j.islower():
                    new_word.append(j.lower())
                else:
                    split = re.split("(?=[А-ЯA-Z\_])", j)[1:]
                    if split is not []:
                        for x in split:
                            new_word.append(x.lower())
            #new_word
            wd_2[i] = {}
            wd_2[i]['done'] = 'maybe'
            wd_2[i]['word'] = ' '.join(new_word)
        else:
            b.append(i)
    print('STEP 3')
    slahes = {}
    wd_3 = {}
    c = []
    for i in b:
        z = text.lower()
        text = i.lower()
        text = re.sub(r'[{}]'.format(''.join([x for x in string.punctuation if x not in ['/', '.', '-', "'"]])), ' ', text)
        words = re.findall(r'\b[a-zA-Zа-яА-ЯеЁ]+\b', text)
        new_word = re.findall(r'\b[a-za-я]{1}/[a-za-я]{1}\b', text)
        sub3 = re.sub(r'\b[a-zA-Zа-яА-ЯеЁ]+\b', ' ', text)
        if new_word != []:
            for j in new_word:
                if j in slahes.keys():
                    slahes[j].append(text)
                else:
                    slahes[j] = []
        if ' '.join(words) == text:
            wd_3[i] = {}
            wd_3[i]['done'] = 'maybe'
            for u in new_word:
                if u in perevod.keys():
                    if any([u == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                        if any([u == x for x in ['т/в', 'тв', 'vsop']]):
                            words.append('туалетная вода')
                        else:
                            words.append('парфюмерная вода')
                    else:
                        words.append(perevod[l])
                else:
                    words.append(l)
            wd_3[i]['word'] = ' '.join(words)
        else:
            c.append(i)  
    print('STEP 4')
    wd_4 = {}
    num = 0
    step4 = []
    for i in c:
        z = i.lower()
        text = re.sub(r'[{}]'.format(string.punctuation), ' ', z)
        words = re.findall(r'\b[a-zA-Zа-яА-ЯеЁ]+\b', text)
        if re.search('\d+', z) is None:
            if ' '.join(words) == text:
                w = re.split('[ ,]', z)
                words = []
                for u in w:


                    if re.search(r'\w{2,}[-]\w{2,}|\w{3,}[.]\w{3,}|\w{2,}\/\w{2,}', u) is not None:
                        if u in perevod.keys():
                            words.append(perevod[u])
                        else:
                            for l in re.split('[-.\/]', u):
                                if l in perevod.keys():
                                    words.append(perevod[l])
                                else:
                                    words.append(l)
                    else:
                        if u in perevod.keys():
                            words.append(perevod[u])

                        elif re.search(r'\bд/[a-zA-Zа-яА-ЯеЁ]+\b', u) is not None:
                            words.append('для ' + u.split('/')[-1])
                        else:
                            words.append(u)
                wd_4[i] = {}
                wd_4[i]['done'] = 'maybe'
                wd_4[i]['word'] = ' '.join(words)
                num +=1
            else:
                step4.append(i)
        else:
            step4.append(i)
    print('STEP 5')
    num = 0
    step5 = []
    wd_5 = {}
    for i in step4:
        z = i.lower()
        # text = re.sub(r'[{}]'.format(string.punctuation), ' ', z)
        words = re.findall(r'\b[a-zA-Zа-яА-ЯеЁ]+\b', z)
        if re.search('\d+', z) is None:
            w = re.split('[\(\), .]', z)
            words = []
            for u in w:
                if re.search(r'\w{2,}[-]\w{2,}|\w{3,}[.]\w{3,}|\w{2,}\/\w{2,}|\w{2,}[.,\/]|\(\w{2,}\)|\(\w{2,} \w{2,}\)', u) is not None:

                    if u in perevod.keys():
                        if any([u == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                            if any([u == x for x in ['т/в', 'тв']]):
                                words.append('туалетная вода')
                            else:
                                words.append('парфюмерная вода')
                        else:
                            words.append(perevod[u])
                    else:
                        for l in re.split('[-.\/\(\)\\" ]', u):
                            if l in perevod.keys():
                                if any([l == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                                    if any([l == x for x in ['т/в', 'тв']]):
                                        words.append('туалетная вода')
                                    else:
                                        words.append('парфюмерная вода')
                                else:
                                    words.append(perevod[l])
                            else:
                                words.append(l)
                else:
                    if u in perevod.keys():
                        if any([u == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                            if any([u == x for x in ['т/в', 'тв']]):
                                words.append('туалетная вода')
                            else:
                                words.append('парфюмерная вода')
                        else:
                            words.append(perevod[u])

                    elif re.search(r'\bд/[a-zA-Zа-яА-ЯеЁ]+\b', u) is not None:
                        words.append('для ' + u.split('/')[-1])

                    elif len(u) == 1:
                        None
                    else:
                        words.append(u)
            wd_5[i] = {}
            wd_5[i]['done'] = 'maybe'
            text = re.sub(r'[{}]'.format(string.punctuation), ' ', ' '.join(words))
            if text.split() != []:
                if text.split()[0].endswith('илин'):
                    wd_5[i]['word'] = text.split()[0]
                else:
                    wd_5[i]['word'] = ' '.join([x for x in text.split()])
            else:
                wd_5[i]['word'] = i
            num +=1
        else:
            step5.append(i)
    print('STEP 6')
    
    sum_dict = {   
    'аи': 'заправка автотранспорт топливо евро газовая колонка', 
    'k5': 'заправка безопасное топливо евро газовая колонка', 
        'к5': 'заправка безопасное топливо евро газовая колонка',
    'а': 'заправка автотранспорт топливо евро газовая колонка', 
    '92': 'заправка бензин евро газовая колонка', 
    '95': 'заправка бензин евро газовая колонка', 
    '98': 'заправка бензин евро газовая колонка',
    '95е': 'заправка бензин евро газовая колонка', 
    'аи92': 'заправка автотранспорт топливо бензин евро газовая колонка', 
    'трк': 'заправка топливо газовая колонка', 
        'бензин': 'бензин', 
        'автомобиль': 'автотранспорт', 
        'джет': 'джет', 
        'премимум': 'премиум', 
        'класс': 'класс', 
        'колонка': 'колонка'}
    
    sum_dict_category_9 = {'диз': 'дизельное', 
                       'топ': 'топливо', 'дт': 'дизельное топливо', 
                       'колонка': 'колонка', 'дизельное': 'дизельное', 
                       'суг': 'сниженные углеводороные газы дизельное топливо', 
                       'танеко': 'производитель дизельное топливо', 
                       'пбт': 'пропан бутан технический дизельное топливо', 
                       'k5': 'заправка дизельное топливо', 'е': 'межсезонное', 
                       'л': 'летнее', 'з': 'зимнее', 
                       'еврос': 'европейский', '92': 'вид топливо', 'к5': 'заправка дизельное топливо', 
                      'трк': 'заправка', 'tpk': 'заправка'}
    
    num = 0
    step6 = []
    wd_6 = {}
   
    for i in step5:
        z = i.lower()
        text = re.sub('\d+', ' ', z)
        #words = re.findall(r'\b[a-zA-Zа-яА-ЯеЁ]+\b', text)
        words = []
        s = "[аи|а|a|aи]{1,}[- ][0-9]{2,}[\w\/]{1,}[- ][0-9]{2,}[- ]\w\d|[\w\/]{1,}[- ][0-9]{2,}-\w\d|[аи|а|a|aи]{1,}[0-9]{2,}-\w\d|[аи|а|a|aи]{1,}[0-9-]{2,}"
        if len(re.findall(r'{}'.format(s), z)) != 0:
            s = "[аи|а|a|aи]{1,}[- ][0-9]{2,}[\w\/]{1,}[- ][0-9]{2,}[- ]\w\d|[\w\/]{1,}[- ][0-9]{2,}-\w\d|[аи|а|a|aи]{1,}[-+ | 0-9]{2,}[0-9a-zа-я]{2,}|[аи|а|a|aи]{1,}[0-9]{2,}-\w\d|[аи|а|a|aи]{1,}[0-9-]{2,}|трк|бензин|автомобильный|джет|премиум|класс|колонка|95"
            new_wo = re.findall(r'{}'.format(s), z)
            
            for we in new_wo:
                my = re.split('[\(\), /+-]', we)
                for m in my:
                    if m in sum_dict.keys():
                        words.append(sum_dict[m])
            wd_6[i] = {}
            wd_6[i]['done'] = 'maybe'
            wd_6[i]['word'] = ' '.join(words)
            
        
        elif len(re.findall(r'{}'.format("дт[_ -]\w{1,}[_ -]\w\d|дт[_ -]\w{1,}|суг|пбт|трк|tpk|танеко"), z)) != 0:
            s = "дт[_ -]\w{1,}[_ -]\w\d|дт[_ -]\w{1,}|трк|tpk|92|диз|топливо|дт|колонка|топ|дизельное|суг|танеко|пбт"
            new_wo = re.findall(r'{}'.format(s), z)
            for we in new_wo:
                my = re.split('[\(\), /+-]', we)
                for m in my:
                    if m in sum_dict_category_9.keys():
                        words.append(sum_dict_category_9[m])
            wd_6[i] = {}
            wd_6[i]['done'] = 'maybe'
            wd_6[i]['word'] = ' '.join(words)
        
        elif re.search('\d+', text) is None:
            w = re.split('[\(\), .]', text)
            for u in w:
                if re.search(r'\w{2,}[-]\w{2,}|\w{3,}[.]\w{3,}|\w{2,}\/\w{2,}|\w{2,}[.,\/]|\(\w{2,}\)|\(\w{2,} \w{2,}\)', u) is not None:

                    if u in perevod.keys():
                        words.append(perevod[u])
                    else:
                        for l in re.split('[-.\/\(\)\\" ]', u):
                            if l in perevod.keys():
                                if any([l == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                                    if any([l == x for x in ['т/в', 'тв', 'vsop']]):
                                        words.append('туалетная вода')
                                    else:
                                        words.append('парфюмерная вода')
                                else:
                                    words.append(perevod[l])
                            else:
                                words.append(l)
                else:
                    if any([u == x for x in ['т/в', 'п/в', 'пв', 'тв', 'vsop']]) and any([x in z for x in ['ml', 'м', 'мл', 'одек', 
                                                                                                           'одеколон', 'bruno', 'tentation', 
                                                                                                           'gracia', 'milady']]):
                        if any([u == x for x in ['т/в', 'тв', 'vsop']]):
                            words.append('туалетная вода')
                        else:
                            words.append('парфюмерная вода')
                    elif u in perevod.keys():
                            words.append(perevod[u])
                    elif re.search(r'\bд/[a-zA-Zа-яА-ЯеЁ]+\b', u) is not None:
                        words.append('для ' + u.split('/')[-1])

                    elif len(u) == 1:
                        None
                    else:
                        words.append(u)
            wd_6[i] = {}
            wd_6[i]['done'] = 'maybe'
            text = re.sub(r'[{}]'.format(string.punctuation), ' ', ' '.join(words))
            if text.split() != []:
                if text.split()[0].endswith('илин'):
                    wd_6[i]['word'] = text.split()[0]
                else:
                    wd_6[i]['word'] = ' '.join([x for x in text.split()])
            else:
                wd_6[i]['word'] = ' '.join(words)
            num +=1
        else:
            step6.append(i)
    LARGE_DICT = {}
    for i in [wd, wd_2, wd_3, wd_4, wd_5, wd_6]:
        LARGE_DICT.update(i)
    vocab_large_dict = {k: ' '.join([' '.join((re.sub(r'[{}]'.format(string.punctuation + '№'), 
                                            '', 
                                            re.sub('k', 'к', x)).replace('\\', '')).split(' ')) for x in w['word'].split(' ')])
                        for k, w in LARGE_DICT.items()}
    
    
    vocab_large_dict = {k: ' '.join([re.sub('k', 'к', re.sub(r'[{}]'.format(string.punctuation), '', perevod[x] if x in perevod.keys() else x)) for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    print('MAPPING....')
    vocab_large_dict = {k: ' '.join(['кислота' if x == 'к' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'та' else x for x in w.split(' ') if x != 'та']) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['мороженое' if x == 'м' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'е' else x for x in w.split(' ') if x != 'е']) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['внутреннее применение' if x == 'вн' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'пр' else x for x in w.split(' ') if x != 'пр']) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['раствор' if x == 'р' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'р' else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['спортивный тренировочный инвентарь силовые тренировки' if x == 'speed' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'bag' else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['попкорн' if x == 'поп' and x != w.split(' ')[-1] and w.split(' ')[w.split(' ').index(x) + 1] == 'корн' else x for x in w.split(' ') if x != 'корн']) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join([perevod[x] if x in perevod.keys() else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['праздник ' + x if x in prazdnik else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    if do_lemma:
        vocab_large_dict = {k: ' '.join([lru_lemmatizer(x) for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
        vocab_large_dict = {k: ' '.join([perevod[x] if x in perevod.keys() else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['замороженная продукция ' + x if x in lemir else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['консервная баночная продукция ' + x if x in maslin else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    vocab_large_dict = {k: ' '.join(['праздник ' + x if x in prazdnik else x for x in w.split(' ')]) for k, w in vocab_large_dict.items()}
    train_data['preprocess'] = train_data['item_name'].map(vocab_large_dict)
    return vocab_large_dict, train_data

# %% [markdown]
# А далее мой словарь сокращений...

# %%
l = set(['эскимо', 'пломбир', 'чебурек', 'чебупели', 'хинкали', 
   'вареник', 'вареники', 'блины', 'блинчики', 'бефстроганов', 'лазанья', 'лед', 'манты',
     'мираторг', 'мороженое',  'пельмени', 'пломбир', 'рожок', 
         'стаканчик',  'булгур', 'сорбет', 
          'пельмени', 'чевапчичи',
     'голубцы',  'брокколи'])
maslin = set(['аджика', 'варенье', 'джем', 'желе', 
             'квашеная', 'консервы', 'лечо', 'маслины', 'мёд', 'оливки', 'паштет', 'сайра', 
              'повидло', 'фасоль', 'шпроты'])

prazdnik = ['выходной', 'боулинг', 'бенгальский', 'аренда', 'пузыри', 'батут', 'шар', 'дискотека', 
           'безлимит', 'аттракцион', 'детский', 'городок', 'огни', 'бар', 'день', 'парк', 'вход', 
            'веселье', 'веселие', 'заезд', 'караоке', 'катание', 'лед', 'лёд', 'льду', 'петарды',
           'катание', 'массовое', 'мыльные', 'радужные', 'хлопушка', 'подарок', 'поздравление', 'баня', 'залпы',
           'свадьба', 'свеча', 'турист', 'мир', 'фейерверки', 'дым', 'фейерверк', 'шар', 'воздушный', 'юбилей', 
           'скидка', 'миллион']

perevod = {'в/с': 'высший сорт', 
           'б/к': 'без костей', 
           'в/у': 'вакуумная упаковка', 
           'м/у': 'мягкая упаковка', 
           'с/к': 'сырокопченая', 
           'ж/б': 'жестяная банка', 
           'п/к': 'полукопченая', 
           'с/м': 'свежемороженый', 
           'ж/р': 'жевательная резинка', 
           'б/г': 'без головы', 
           'б/п': 'большая пачка',
           'п/о': 'пленочная оболочка', 
           'з/п': 'зубная паста', 
           'с/б': 'стеклянная бутылка', 
           'х/к': 'холодное копчение', 
           'ц/о': 'целлофановая оболочка', 
           'б/а': 'безалокогольные', 
           'д/п': 'детское питание',  
           'm/l': 'размер', 
           'з/щ': 'зубная щётка', 
           'п/ф': 'полуфабрикат', 
           'ветч/сыр': 'ветчина сыр', 
           'д/пола': 'для пола', 
           'д/уборки': 'для уборки', 
           'с/с': 'слабо соленая', 
           'охл': 'охлажденная', 
           'д/чист': 'для чистки', 
           'д/колки': 'для колки', 
           'н/р': 'неразделанный', 
           'д/кош': 'для кошки', 
           'туал': 'туалет', 
           'асс-те': 'ассортименте', 
           'пив': 'пивной', 
           'д/м': 'для мужчин', 
           'д/ж': 'для женщин', 
           'д/выпеч': 'для выпечки', 
           'ст': 'стандартный', 
           'стд': 'стандартный', 
           'картоф': 'картофель', 
           'порц': 'порция', 
           'бол': 'большая', 
           'бкомбо': 'большое комбо', 
           'скомбо': 'среднее комбо', 
           'пласт': 'пластиковый', 
           'ср': 'средний', 
           'мал': 'маленький', 
           'табачн': 'табачные', 
           'кокт': 'коктейль', 
           'асс': 'ассортименте', 
           'чл': 'чистая линия', 
           'р-ра': 'раствора', 
           'нап': 'напиток', 
           'энерг': 'энергетический', 
           'ябл': 'яблоко', 
           'фр': 'фрутелла', 
           'автом': 'автомобильная', 
           'шариков': 'шариковых', 
           'мрам': 'мраморной', 
           'гов': 'говядины', 
           'ОСТАН': 'останкинское', 
           'фил': 'филе', 
           'зап': 'запеченное', 
           'прод': 'продукт', 
           'йог': 'йогурт', 
           'устройс': 'устройство', 
           'арб': 'арбуз', 
           'дын': 'дыня', 
           'д/тетрад': 'для тетрадка', 
           'содерж-е': 'содержание', 
           'малин': 'малиновый', 
           'нач': 'начинка', 
           'кукур': 'кукуруза', 
           'карамел': 'карамель', 
           'мясн': 'мясной', 
           'смород': 'смородина', 
           'респуб': 'республика', 
           #'гр': 'грамм', 
           #'кг': 'килограмм', 
           #'шт': 'штук', 'руб': 'рубль', 
           'алког': 'алкоголь', 
           'п/сл': 'полусладкое', 'алк': 'алкоголь', 'фрукт': 'фруктовый', 
           'п/сух': 'полусухое', 'сух': 'сухое', 'кр': 'красное', 'вин': 'вино', 
           'сх': 'сухое', 'красн': 'красное', 'крас': 'красное', 
           'бел/сух': 'белое сухое', 'бут': 'бутылка',
           #'шамп': 'шампанское',
           'шампань': 'шампанское', 
           'шампусик': 'шампанское', 'бел': 'белое', 
           'ж/б': 'железная бутылка', 'б/алк': 'без алкоголь', 
           'б/сух': 'белое сухое', 
           'б': 'белое', 'светл': 'светлое', 
           'балтитка': 'балтика', 'шымкентское': 'шампанское', 
           'п/слад': 'полусладкое', 'жб': 'железная банка',
           'н/ф': 'не фильтрованное', 'н\ф': 'не фильтрованное', 'сл': 'сладкое', 
           'фильт': 'фильтрованное', 'нефильт': 'не фильтрованное', 'жив': 'живое', 
           'п/у': 'прозрачная упаковка', 'алко': 'алкоголь', 'глинтв': 'глинтвейн', 
           #'мл': 'миллиграмм',
           'омсквинпром': 'оксимирон', 
           #'ml': 'миллиграмм', 
           'глинтв.': 'глинтвейн', 'п/с': 'полусладкое', 
           'ж\б': 'железная банка', 'сп': 'спирт', 'спир': 'спирт', 
           'ш-е': 'шампанское', 
           'мягк': 'мягкое', 'н/фил': 'не фильтрованное', 
           'п/уп': 'пластиковая упаковка', 'стар': 'старый', 'бел/сух': 'белый сухой', 'игр': 'игристый', 
           'псх': 'полусухое', 'псл': 'полусладкое', 
           'блсх': 'белое сухое', 'кр/сух': 'красное сухое', 'крсх': 'красное сухое', 'водк': 'водка', 
           'с/а': 'слабо алкогольный', 'слабоалк': 'слабо алкогольный', 
           'слаб': 'слабый', 'слабоал': 'слабо алкогольный', 'ос': 'особая', 
           'бл': 'белое', 'рз': 'розовый', 'игр': 'игристое', 
           'газ': 'газированный', 'водакока': 'водка', 'боч': 'бочонок', 
           'бочон': 'бочонка', 'пивн': 'пивной', 'пив': 'пивной', 
           'през': 'презерватив', 
           'презер': 'презерватив', 'презерв': 'презерватив', 
           'conte': 'contex', 'cont': 'contex', 'дюрекс': 'durex', 
           'сверхтонк': 'сверхтонкие', 'смазк': 'смазка', 'ошибк': 
           'ошибка', 'контекс': 'contex', 'сиг': 'сигареты', 
           'классич': 'классический', 'ассорт': 'ассорти', 
           'сигаретывинстонблю': 'сигареты винстон блю', 
           'сигаретывинстонсильвер': 'сигареты винстон сильвер', 
           'таб': 'табак', 'сигаретылд': 'сигареты', 
           'сигаретытройка': 'сигареты тройка', 
           'сигаретыява': 'сигареты ява', 'l&m': 'LM', 
           'мрц': 'максимально розничная цена', 
           'силвер': 'сильвер', 
           'c-ты': 'сигареты', 'нагр': 'нагреваемые',
           'нагрев': 'нагреваемые', 'табач': 'табак', 
           'жидк': 'жидкий', 'испар': 'испарение', 
           'масл': 'масляный', 'возд': 'воздушный', 
           'торм': 'тормозная', 'рем': 'ремень', 'д/ш': 'для шин', 
           'насад': 'насадка', 'автомоб': 'автомобиль', 
           'с/о': 'стеклоочистителя', 'со': 'стеклоочистителя', 
           'оч': 'стеклоочистителя', 'очист': 'стеклоочистителя', 
           'стеклоочис': 'стеклоочистителя', 
           'стеклооч': 'стеклоочистителя', 'а/м': 'ароматизатор', 
           'вел': 'велосипед', 'бескарк': 'бескаркасная', 'наб': 'набор', 
           'антиф': 'антифриз', 'аром': 'аромат', 'гермет': 'герметик', 'мот': 'моторное', 
           'жид-ть': 'жидкость', 
           'кан': 'канцелярский', 'унив': 'университет', 'тв': 'телевизор', 
           'жур': 'журнал', 'журн': 'журнал', 'ж-л': 'журнал', 'новос': 'новости', 
           'сканв': 'сканворды', 'настоль': 'настольных', 'канц': 'канцелярские', 
           'мелоч': 'мелочей','бейдж': 'бейджик', 'самокл': 'самоклеющаяся', 
           'быстросохн': 'быстро сохнущая', 'клейк': 'клейкая', 'колп': 'колпачок', 
           'цв': 'цвет', 'скоросшиват': 'скоросшиватель', 
           'карт': 'картонный', 'тетр': 'тетрадь', 'свидетел': 'свидетельство', 'заключ': 'заключение', 
           'скоросшив': 'скоросшиватель', 'цветн': 'цветные', 
           'каранд': 'карандаш', 'черн': 'черная', 'ч/г': 'чернографитный', 
           'ч/гр': 'чернографитный', 'платиковый': 'платиковый', 'руч': 'ручка', 
           'гел': 'гелевая', 'чер': 'черная', 'прост': 'простой', 
           'шарик': 'шариковый', 'н/р': 'набор ручек', 'нб': 'набор', 'прозр': 'прозрачный', 'колпач': 'колпачок',
           'гелев': 'гелевая', 'капил': 'капиллярная', 'кап': 'капиллярная', 'син': 'синяя', 'чёрн': 'черная',
          'дневн': 'дневник', 'обл': 'область', 'шк': 'школьная', 'кл': 'класс', 'ежед': 'ежедневник', 
           'ежедн': 'ежедневник', 'синт': 'синтетический', 'кар': 'карандаш', 'клейкарандаш': 'клей карандаш', 
          'рус/яз': 'русский язык', 'кист': 'кисточки', 'раб': 'рабочая', 'накл': 'наклейка', 'ножн': 'ножницы', 
           'днев': 'дневник', 'тет': 'тетрадь', 'универс': 'университет', 'проп': 'пропись', 'дошк': 'школьник', 
           'самоклбумагад': 'самоклеющаяся', 'пап': 'папка', 'отд': 'отделение', 'молн': 'молния', 'глянц': 'глянцевый', 
           'зел': 'зеленый', 'многоцв': 'много цветов', 'заточен': 'заточенный', 'худож': 'художник', 'акв': 'акварель', 
           'леп': 'лепения', 'фломаст': 'фломастер', 'разноцв': 'разноцветный', 'точилкимп': 'точилка', 'раск': 'раскраска',
          'бумаа': 'бумага', 'аромапалочки': 'арома палочки', 'ароматичес': 'ароматический', 'аромнаб': 'арома', 
           'ароматич': 'ароматический', 'эфирн': 'эфирное', 'витамир': 'витамин', 'витаминно': 'витамин', 
           'капс': 'капсулы', 'аевитамины': 'витамины', 'вит': 'витамины', 'жев': 'жевательный', 
           'жеват': 'жевательный', 'к/та': 'кислота', 'обогащ': 'обогащенный', 'вита': 'витамин', 'актив': 'активный', 
          'красногорсклексредства': 'средства', 'стм': 'собственная торговая марка', 'дет': 'детская', 'трубоч': 'трубочка', 
           'подг': 'подгузник', 'подгузн': 'подгузник', 
           'клубн': 'клубничный', 'з/паста': 'зубная паста', 'туалетн': 'туалетное', 'п/заг': 'после загара', 'ручк': 'ручка',
          'влаж': 'влажные', 'экстр': 'экстрат', 'салф': 'салфетка', 'косм': 'косметика', 'пен': 'пена','шам': 'шампунь', 
          'увл': 'увлажнение', 'нат': 'натуральный', 'взр': 'взрослый', 'пел': 'пеленка', 
           'пелен': 'пеленка', 'блест': 'блестящий', 'профилакт': 'профилактика', 'мес': 'месяц', 'сусп': 'суспензия', 
           'наз': 'назальные','назал': 'назальные', 'лексредства': 'лекарство средства', 'увлажняющ': 'увлажняющие', 
           'капс': 'капсулы', 'тбл': 'таблетки', 'водн': 'водный', 'вн/пр': 'внутреннее применение', 'внут': 'внутрь', 
           'табл': 'таблетки', 'наружн': 'наружное', 'прим': 'примение', 'р/ра': 'раствор', 'држ': 'драже', 
          'аэроз': 'аэрозоль', 'аэр': 'аэрозоль', 'к/ты': 'кислота', 'н/ка': 'настойка',  'р-ра': 'раствор',
          'изготовл': 'изготовление', 'пластм': 'пластмассовая', 'оправе': 'оправа', 'конт': 'контактных', 
           'увлажн': 'увлажняющие', 'салфет': 'салфетка', 'auraвлсалф': 'салфетка', 'бум': 'бумага', 
           'влсалфунив': 'салфетка', 'проклад': 'прокладка', 'зп': 'зубная паста', 'полоск': 'полоскание', 
           'антиб': 'антибактериальный', 'ватн': 'ватные', 'вл': 'влажные', 'влажн': 'влажные', 'сал': 'салфетка', 
          'дез': 'дезодарант', 'невид': 'невидимый', 'муж': 'мужской', 'з/щетка': 'зубная щетка', 'з/щ': 'зубная щетка',
          'мятн': 'мятный', 'прокл': 'прокладка', 'зуб': 'зубная', 'туалетнаябумага': 'туалентная бумага',
           'туалет': 'туалетная', 'эл': 'электронная', 'тб': 'туалетная бумага', 'матир': 'матирующий', 
          'тон': 'тональный', 'косме': 'косметичка', 'подводк': 'подводка', 'удл': 'удлинить', 'снят': 'снятия', 
           'быстрыйэф': 'быстрый эффект', 'кальц': 'кальций', 'укре': 'укрепления', 'укреплен': 'укрепления', 'сн': 'снятия',
          'компл': 'комплект', 'лит-ра': 'литература', 'кн': 'книга', 
           #'изд': 'издательство', 
           'сер': 'серия', 'уч': 'учебник', 
          'беременност': 'беременность', 'беременн': 'беременность', 'стер': 'стерильный', 'ant': 'антисептик', 
           'antisepti': 'антисептик', 'медиц': 'медицина', 'сте': 'стерильный', 'трубч': 'трубчатый', 'обув': 'обувь',
          'марл': 'марлевый', 'марлев': 'марлевый', 'мед': 'медицина', 'повяз': 'повязка', 'л/пл': 'лейкопластырь',
          'смотр': 'смотровые', 'стерил': 'стерильный', 'опр': 'опеделения', 'берем': 'беременность',
          'одн': 'одноразовый', 'однор': 'одноразовый', 'однораз': 'одноразовый', 'лейкопл': 'лейкопластырь', 
           'изг-е': 'изготовление', 'мрт': 'магниторезонансная терапия', 'кт': 'компьютерная томография', 
           'орт': 'ортопед', 'спец': 'специальный', 'хир': 'хирургия', 'одек': 'одеколон', 'туал': 'туалетная', 
           'п/в': 'парфюмерная вода', 'сыв': 'сыворотка', 'кож': 'кожа', 'вол': 'волосы', 'массажн': 'массаж', 
           'прочи': 'прочее',
            'шамп': 'шампунь', 'шп': 'шампунь', 'шампhs': 'шампунь', 'укреп': 'укрепление', 'золо': 'золотой',
          'бальз': 'бальзам', 'ш-нь': 'шампунь', 'жир': 'жирные', 'ослаб': 'ослабленных', 'секущ': 'секущиеся',
          'конд': 'кондиционер', 'кон': 'кондиционер', 'кондиц': 'кондиционер', 'бров': 'брови', 'сиян': 'сияние',
          'трав': 'травы', 'перх': 'перхоть', 'шмп': 'шампунь', 'жем': 'жемчужина', 'умыв': 'умывания', 
          'сыворот': 'сыворотка', 'брит': 'бритья', 'очищ': 'очищающий', 'чж': 'черная жемчужина', 'черн': 'черный', 
          'скр': 'скраб', 'касеты': 'кассеты', 'ноч': 'ночной', 'дн': 'дневной', 'восстан': 'восстанавливающая', 
          'интенс': 'интенсивный', 'натур': 'натуральный', 'барх': 'бархатные', 'жен': 'женская', 'освежающ': 'освежающая',
          'ж/мыло': 'женское мыло', 'д/рук': 'для рук', 'жид': 'жидкое', 'ванн': 'ванна', 'т/мыло': 'туалетное мыло',
          'пиявк': 'пиявка', 'шер': 'шерсть', 'трик': 'трикотажные', 'брюкик': 'брюки', 'брюкир': 'брюки', 
          'женс': 'женские', 'мальч': 'мальчик', 'мужска': 'мужская', 'джинс': 'джинсы', 'полуб-ки': 'полуботинки',
          'п/ботинки': 'полуботинки', 'рез': 'резина', 'сап': 'сапоги', 'ж': 'женская', 'д/об': 'для обуви', 
           'бюстгальт': 'бюстгальтер', 'бюст': 'бюстгальтер', 'бюстгалтер': 'бюстгальтер', 'колг': 'колготки',
          'кол': 'колготки', 'колготкиtgb': 'колготки', 'колготы': 'колготки', 'трус': 'трусы', 'трусики': 'трусы',
          'утепл': 'утепленный', 'футб': 'футболка', 'блуза': 'блузка', 'нос': 'носки',
          'пиджакк': 'пиджак', 'пиджакр': 'пиджак', 'укороч': 'укороченный', 'комфорт': 'комфортный', 'диз': 'дизельное', 
           'зим': 'зимняя', 'элит': 'элитный', 'легг': 'легинсы', 'шор': 'шорты', 'ветчинагрибы': 'ветчина грибы', 
           'замор': 'замороженная', 'кус': 'кусочек', 'ветчин': 'ветчина', 'пиццааппетитная': 'пицца', 
           'пиццаветчина': 'пицца ветчина', 'пиццаролл': 'пицца ролл', 'выпеченн': 'выпеченный', 'моцарел': 'моцарелла',
          'ветч': 'ветчина', 'pizza': 'пицца', 'pepperoni': 'пицца пепперони', 'capricciosa': 'пицца capricciosa', 
          'баварская': 'баварская пицца', 'пепперончини': 'пицца пепперони', 'пепперони': 'пепперони пицца', 
           'сыра': 'сыра пицца', 'телепицца': 'телепицца пицца', 'мексиканская': 'мексиканская пицца', 
           'капричеса': 'пицца капричеса', 'гавайская': 'гавайская пицца', 'филадельфия': 'филадельфия ролл', 
          'миниролл': 'мини ролл', 'копч': 'копченой', 'гамбургер': 'бургер', 'роял': 'роял бургер', 
           'роялбургер': 'роял бургер', 'сандвич': 'сэндвич', 'сендвич': 'сэндвич', 'фрешбургер': 'фреш бургер', 
           'шефбугер': 'шеф бургер', 'чикенсандвич': 'чикен сэндвич', 'шефбургер': 'шеф бургер', 'burger': 'бургер',
          'кур': 'куриные', 'остр': 'острый', 'жаренн': 'жаренный', 'лук': 'луковые', 'клас-кие': 'классические',
          'острмакнаггет': 'острые макнаггетс', 'свин': 'свинина', 'классик': 'классическая', 'тарел': 'тарелка',
          'чик': 'чикен', 'бек': 'бекон', 'макнаггетс': 'мак наггетс', 'нагетсы': 'наггетсы',
          'ланчбаскет': 'ланч баскет', 'ланчбокс': 'ланч бокс', 'штстрипсы': 'стрипсы', 'шткур': 'куриные', 
           'станд': 'стандартный', 'чикенбокс': 'чикен бокс', 'чикенбургер': 'чикен бургер', 
           'чикеннаггетсы': 'чикен наггетсы', 'чикенмак': 'чикен мак', 'чикенстар': 'чикен стар', 
           'чизбургер': 'чиз бургер сыр', 'макфреш': 'мак фреш', 'боксмастер': 'бокс мастер',
          'америк': 'американо', 'ассам': 'чай ассам', 'американоg': 'американо', 'анчан': 'чай анчан',
          'аффогато': 'кофе аффогато', 'capuccino': 'капучино', 'capuccino': 'капучино', 'бразил': 'бразильский',
          'гляссе': 'кофе гляссе', 'латте': 'кофе латте', 'латтэ': 'кофе латте',
           'капучино': 'кофе каппучино', 'американо': 'кофе американо',
          'каппучино': 'кофе каппучино', 'капучиноg': 'каппучино', 'коф': 'кофе', 'напит': 'напиток', 
           'кортадо': 'кофе кортадо', 'мокко': 'кофе мокко', 'майский': 'майский чай', 'эспрессо': 'кофе эспрессо', 
           'эспресо': 'кофе эспрессо', 'мол': 'молоко', 'раф': 'раф кофе', 'розлив': 'розливной', 'раст': 'растительный',
          'сенча': 'чай сенча','мокачино': 'кофе мокачино','моккачино': 'кофе мокачино', 'мокаччино': 'кофе мокачино',
          'ройбуш': 'чай ройбуш', 'фкапучино': 'капучино', 'капуччино': 'кофе каппучино', 'капучинно': 'кофе каппучино',
          'espresso': 'эспрессо', 'фраппе': 'кофе фраппе', 'рухуна': 'чай рухуна', 'амерекано': 'кофе американо',
          'биф': 'бифштекс', 'картофе': 'картофель', 
           'аджапсандали': 'блюдо из баклажан помидор сладкий перец лук чеснок', 
           'акцияшашлык': 'акция шашлык', 'балоньезе': 'паста макароны', 'биточки': 'биточек', 'блинный': 'блин', 
           'фрик': 'фрикаделька', 'бризоль': 'курица мясо свинина сыр', 'гаспачо': 'суп пюре помидор огурец', 
           'блинчик': 'блин',
           'доп': 'дополнительный', 'долма': 'виноград лист баранина масло свинина',
          'морск': 'морской', 'жар': 'жареный', 'котл': 'котлета', 'котлет': 'котлета', 'свеж': 'свежей',
          'фокачо': 'лепешка', 'фокача': 'лепешка', 'фокачча': 'лепешка', 'с-т': 'салат', 'с/т': 'салат', 
           'колб': 'колбаса', 'класс': 'классический', 'говяд': 'говядина', 'болоньезе': 'паста макароны', 
           'хрустящ': 'хрустящий', 'неж': 'нежный', 'дп': 'детское питание', 'черносл': 'чернослив', 
           'фрутоняня': 'фруто няня', 'земл': 'земляника', 'фрняня': 'фруто няня', 'детск': 'детский',
          'яблклуб': 'яблоко клубника', 'перс': 'персик', 'лесн': 'лесные', 'биойог': 'био йогурт', 'фрук': 'фруктовые',
          'фн': 'фруто няня', 'ф-н': 'фруто няня', 'спаг': 'спагетти макароны', 'молсмесь': 'молоко смесь',
          'баблукпюре': 'бабушкино лукошко пюре', 'баб': 'бабушкино', 'овсян': 'овсяное', 'черни': 'черничный',
          'молсмесьсимилакголд': 'молоко смесь симилак голд', 'неосвет': 'неосветленный', 'осветл': 'осветленный',
          'биотв': 'био творог', 'биотворог': 'био творог', 'бзмж': 'без заменителя молочного жира', 
           'бзмжмороженое': 'бзмж мороженое', 'блинч': 'блинчики', 'заморож': 'замороженный', 'бульмени': 'пельмени',
          'ваф': 'вафли', 'горяч': 'горячая', 'дес': 'десерт', 'краб': 'крабовые', 'змж': 'замороженный',
          'м/е': 'мороженое', 'мират': 'мираторг', 'м-ное': 'мороженое', 'морож': 'мороженое', 'мор': 'мороженое',
          'морожен': 'мороженое','мороженное': 'мороженое', 'карам': 'карамель', 'слоен': 'слоеное', 'стакан':'стаканчик',
          'биомороженое': 'био мороженое', 'капутс': 'капуста', 'филев': 'филе', 'пельм': 'пельмени', 'цыпл': 'цыпленок',
          'эск': 'эскимо', 'п/фаб': 'полуфабрикат', 'п/фабрикат': 'полуфабрикат', 'вар': 'вареная', 
          'в/к': 'великолужский', 'остан': 'останкино', 'сервел': 'сервелат', 'серв': 'сервелат',
          'сос': 'сосика', 'сосис': 'сосиска', 'сард': 'сарделька', 'к-са': 'колбаса', 'грудинкаособаявк': 'грудинка особая',
          'горох': 'горошек', 'горош': 'горошек', 'кваш': 'квашенная', 'квашеная': 'квашенная', 'конс': 'консервы',
          'кукуруз': 'кукуруза', 'кук': 'кукуруза', 'олив': 'оливка', 'верм': 'вермишель',
          'гречн': 'гречневая', 'каш': 'каша', 'овс': 'овсяная', 'кукруза': 'кукуруза', 'ячне': 'ячневая',
          'лапш': 'лапша', 'макарон': 'макароны', 'разрыхлит': 'разрыхлитель','спагет': 'спагетти', 
           'макпр': 'макароны', 'мак/изд': 'макароны изделия','пшеничн': 'пшеничная', 'рж': 'ржаная', 'гречка': 'греча',
          'гречневая': 'греча', 'рисовая': 'рис', 'быстр': 'быстрый', 'спагетти': 'макароны', 'фунчоза': 'макароны',
          'кетч': 'кетчуп', 'ванильн': 'ванильный', 'горчич': 'горчица',
          'подс': 'подсолнечное', 'подсол': 'подсолнечное', 'подсолн': 'подсолнечное', 'подсолнеч': 'подсолнечное',
          'подсолне': 'подсолнечное', 'слив': 'сливочное', 'пасх': 'пасхальный', 'сахарн': 'сахар',
          'наклейкнапасхальняйц': 'наклейка на пасхальные яйца', 'припр': 'приправа', 'повареная': 'поваренная',
          'при/ва': 'приправа', 'при-ва': 'приправа', 'прип': 'приправа','топинг': 'топпинг', 'золот': 'золотая',
          'злато': 'подсолнечное', 'молот': 'молотый', 'йогпит': 'йогурт питьевой', 'биойогурт': 'био йогурт',
          'биогурт': 'био йогурт', 'пит': 'питьевой', 'биокефир': 'био кефир', 'биоваренец': 'био варенец',
          'биоряж': 'био ряженка', 'биопродукт': 'био продукт', 'биоряженка': 'био ряженка','вкусн': 'вкусный',
          'термост': 'термостатный', 'фруатэ': 'фруктовый', 'фрутис': 'фруктовый', 'фруттис':'фруктовый',
          'натуральн': 'натуральный', 'клуб': 'клубника', 'кусоч': 'кусочек', 'греческ':'греческий', 
           'двухсл': 'двухслойный', 'клюкв': 'клюква', 'йогуртн': 'йогурт', 'йогуртнежн': 'йогурт нежный', 
          'йогуртнежныйперсикбзмж': 'йогурт нежный персик бзмж', 'йп': 'йогуртный продукт', 'кеф': 'кефир',
          'жирн': 'жирный', 'пюр': 'пюре', 'молоч': 'молочный', 'молочн': 'молочный', 'шок': 'шоколад',
          'м/з': 'майонез', 'м-з': 'майонез', 'майон': 'майонез', 'прованс': 'провансаль', 'прован':'провансаль',
          'детс': 'детское', 'отборн': 'отборное', 'отбор': 'отборное', 'пастер': 'пастеризованное', 
           'паст': 'пастеризованное', 'сгущ': 'сгущенка', 'сах': 'сахар', 'ультрапаст': 'ультра пастеризованное',
          'ультрап': 'ультра пастеризованное', 'ультр': 'ультра пастеризованное', 'ультроп': 'ультра пастеризованное',
          'ультрапаст': 'ультра пастеризованное', 'ультрпаст': 'ультра пастеризованное',
          'молокодомик': 'молоко домик', 'молокосод': 'молоко содержащий',  'молокосодерж': 'молоко содержащий',
          'сгущен': 'сгущенка', 'стерилиз': 'стерилизованное', 'кисломол': 'кисло молочный', 
           'сзмж': 'содержит заменитель молочных жиров', 'смет': 'сметана',
          'плав': 'плавленый', 'плавл': 'плавленый', 'плавлен': 'плавленый','российск': 'российский', 
          'россий': 'российский', 'глаз': 'глазированные', 'глазир': 'глазированные', 'глазиров': 'глазированные',
          'суфл': 'суфле', 'твор': 'творожный', 'творож': 'творожный', 'темн': 'темный', 'легк': 'легкий',
          'курин': 'куриное', 'цб': 'цыпленок бройлер', 'пф': 'полуфабрикат', 'шеи': 'шея', 'семеч': 'семечки',
           'сем': 'семечки', 'рыбк': 'рыбка', 'принглс': 'чипсы', 'лейс': 'чипсы', 'яблоч': 'яблочные', 
           'читос': 'чипсы', 'чипсоны': 'чипсы', 'хруст': 'хрустящий', 'pringles': 'чипсы', 'lays': 'чипсы', 
           'хрустим' : 'сухарики', 'короч': 'корочки', 'чип': 'чипсы', 'nachos': 'чипсы', 'beerka': 'арахис',
          'воронц': 'воронцовские', 'вял': 'вяленая', 'сопа': 'рыба сопа', 'сибас': 'рыба сибас',
          'вобла': 'рыба вобла', 'кета': 'рыба кета', 'камбала': 'рыба камбала', 'горбуша': 'рыба горбуша', 
           'сельдь':'рыба сельдь', 'анчоус': 'рыба анчоус', 'балык': 'рыба балык', 'вомер': 'рыба вомер',
          'дорада': 'рыба дорада', 'жерех': 'рыба жерех', 'голец': 'рыба голец', 'карп': 'рыба карп', 
           'килька': 'рыба килька', 'каракатица': 'рыба каракатица', 'карась': 'рыба карась', 
           'мореп': 'морепродукты', 'морепрод': 'морепродукты', 'морепродукт': 'морепродукты',
          'морепр': 'морепродукты', 'сайда': 'рыба сайда', 'мин/вода': 'минеральная вода',
           'мин-вода': 'минеральная вода', 'мин': 'минеральная', 'водаборжомистекло': 'вода боржоми стекло',
          'водапитьевая': 'вода питьевая', 'негаз': 'негазированная', 'негазиров': 'негазированная',
          'черног': 'черноголовка', 'минерал': 'минеральная', 'минер': 'минеральная', 'минеральн': 'минеральная',
          'питьев': 'питьевая', 'aqua': 'вода аква минерале', 'minerale': 'вода аква минерале', 'borjomi': 'вода боржоми',
          'анан': 'ананас', 'газир': 'газированная', 'свят': 'святой', 'г/в': 'газированная вода', 
           'газвода': 'газированная вода', 'энергетич': 'энергетический', 'энергет': 'энергетический', 'энер': 'энергетический', 
          'энег': 'энергетик', 'эн': 'энергетический', 'н/к': 'напиток', 'н-к': 'напиток', 'швеп': 'швепс лимонад', 
           'fuse': 'фьюз', 'tea': 'чай', 'минвода': 'минеральная вода', 'сокосод': 'сокосодержащий',
          'сокосодер': 'сокосодержащий', 'сильногаз': 'сильногазированный', 'сокосодерж': 'сокосодержащий',
          'шокол': 'шоколад', 'бат': 'батончик', 'ш-д': 'шоколад', 'ш/д': 'шоколад', 'ш': 'шоколад', 'холс': 'холлс',
          'хлебобулочн': 'хлебобулочное', 'хлебобул': 'хлебобулочное', 'хлебо-булочное': 'хлебобулочное', 
           'хлебо/булочное': 'хлебобулочное', 'ржано': 'ржаной', 'пшенич': 'пшеничный', 'пш': 'пшеничный', 'пшен': 'пшеничный',
          'бул': 'булка', 'х/б': 'хлебобулочное', 'изд': 'изделие', 'пир': 'пирог', 'печен': 'печенье', 'печ': 'печенье',
          'круас': 'круассан', 'круасан': 'круассан', 'круасс': 'круассан', 'круасаны': 'круассан', 'конф': 'конфеты',
          'зефирн': 'зефир', 'резина': 'резинка', 'марм': 'мармелад', 'свадебные': 'свадьба', 
           'танцпола': 'танцпол', 'диско': 'дискотека', 'празднич': 'праздник', 'пневмохлопушка': 'пневмо хлопушка', 
          'пневмохл': 'пневмо хлопушка', 'поздравл': 'поздравление', 'праздничные': 'праздник', 
           'праздничный': 'праздник', 
           'русскаябаня': 'русская баня', 'туристический': 'турист', 'вых': 'выходной', 'н-р': 'набор',
          'хвс': 'холодное водоснабжение', 'вдго': 'внутридомовое газовое оборудование',
          'вкго': 'внутриквартирное газовое оборудование', 'капремонт': 'капитальный ремонт',
          'жбо': 'жидкие бытовые отходы', 'гвс': 'горячее водоснабжение', 
           'сои': 'содержание общедомового имущества', 'ор': 'общедомовые ресурсы', 
           'тко': 'твердые бытовые отходы', 'моп': 'места общего пользования', 
           'хв': 'холодное водоснабжение', 'мкд': 'многоквартиный дом', 'ду': 'управление дома',
          'одн': 'общедомовые нужды', 'одпу': 'общедомовые приборы учета', 'гп': 'государственное предприятие',
          'оди': 'общедомовые нужды', 'вгдо': 'внутридомовое газовое оборудование', 
           'жкх': 'жилищно коммунальное хозяйство', 'ои': 'общее имущество',
          'ипу': 'индивидуальные приборы учета', 'квт': 'киловатт час',
          'жку': 'жилищно коммунальные услуги', 'использ': 'использование', 'содерж': 'содержать', 'общ': 'общее',
          'муп': 'муниципальное унитарное предприятие', 'НДС': 'налог на добавленную стоимость',
          'соджилья': 'содержание жилья', 'пк': 'повыщающий коэффициент', 'дек': 'декабрь', 'окт': 'октябрь',
          'апр': 'апрель', 'повыш': 'повышающий', 'нояб': 'ноябрь', 'отвед': 'отведение', 'обсл': 'обслуживание',
          'квартплат': 'квартирная плата', 'элеснаб': 'электроснабжение', 'взросл': 'взрослый', 
           'ласты': 'бассейн ласты', 'протеиновый': 'протеиновый энергетический спортивное питание',
          'chiкabar': 'энергетический протеиновый спортивное питание набор массы', 
          'monohydrate': 'смесь для ускорения роста мышц протеин спортивное питание заменитель набор массы',
          'energon': 'энергетическое спортивное питание заменитель', 'чамп': 'энергетическое спортивное питание', 
          'белок': 'спортивное питание', 'фитнес': 'фитнес спортивный', 'smart': 'спортивное питание', 
           'eemb': 'энергетический протеиновый спортивное питание для спорта набор массы', 
           'eemm': 'энергетический протеиновый спортивное питание для спорта набор массы', 
           'nutrition': 'протетиновое спортивное питание', 'quest': 'энергетический протеивновый набор массы' , 
           'prot': 'спортивное питание заменитель', 'спортик': 'спортивное питание набор массы', 'турбослим': 'спортивное питание заменитель',
          'соевый': 'спортивное питание заменитель', 'пребиосвит': 'спортивное питание заменитель',
          'samyun': 'набор массы спортивное питание энергетическое', 'wan': 'спортивное питание', 
           'muscle': 'набор массы мускулы спортивное питание',
          'alpinistiк': 'спортивный тренировочный инвентарь', 
           'трос': 'спортивный тренировочный инвентарь силовые тренировки',
           'резинов': 'резиновая', 'скакалка': 'спортивный инвентарь для тренировок прыжки спорт',
          'weight': 'спортивный тренировочный инвентарь силовые тренировки', 
           'weights': 'спортивный тренировочный инвентарь силовые тренировки',
           'гантель': 'спортивный тренировочный инвентарь силовые тренировки', 
           'гантели': 'спортивный тренировочный инвентарь силовые тренировки',
          'гимнастический': 'спортивный тренировочный инвентарь гимнастические тренировки', 
           'гимнастич': 'гимнастический', 'эспандер': 'спортивный тренировочный инвентарь гимнастические тренировки',
          'training': 'спортивный тренировочный инвентарь силовые тренировки', 
          'обруч': 'спортивный тренировочный инвентарь гимнастические тренировки', 
          'тяга': 'спортивный тренировочный инвентарь силовые тренировки', 'рулевая': 'силовые тренировки',
          'утяжелители': 'спортивный тренировочный инвентарь силовые тренировки', 
           'пластмасс': 'пластмассовый', 'silapro': 'спортивный тренировочный инвентарь',
          'starfit': 'спортивный тренировочный инвентарь силовые тренировки', 'оберт':'обертка',
          'пак': 'пакет', 'подар': 'подарок', 'творч': 'творчество', 
           'раскраска': 'художественные принадлежности для творчества  и арт искусство рисование',
         
          'мелки': 'художественные принадлежности для творчества  и арт искусство рисование', 
          'скетчбук': 'художественные принадлежности для творчества  и арт искусство рисование',
          'фломастеры': 'художественные принадлежности для творчества  и арт искусство рисование',
          'фломастер': 'художественные принадлежности для творчества  и арт искусство рисование',
          'трафарет': 'художественные принадлежности для творчества  и арт искусство рисование',
         'разбавитель': 'художественные принадлежности для творчества  и арт искусство рисование', 
           'холст': 'художественные принадлежности для творчества  и арт искусство рисование',
          'раскр': 'раскраска', 'творчество': 'художественные принадлежности для творчества  и арт искусство рисование',
          'альбом': 'художественные принадлежности для творчества  и арт искусство рисование',
          'акварель': 'художественные принадлежности для творчества  и арт искусство рисование',
          'акрил': 'художественные принадлежности для творчества  и арт искусство рисование',
          'мольберт': 'художественные принадлежности для творчества  и арт искусство рисование',
          'акварель': 'художественные принадлежности для творчества  и арт искусство рисование',
          
          'акварель': 'художественные принадлежности для творчества  и арт искусство рисование',
          'кистей': 'художественные принадлежности для творчества  и арт искусство рисование', 
          'держат': 'держатель', 'магнит': 'магнитный', 'реш': 'решетка',
          'гофра': 'трубчатые строительные материалы сантехника', 
           'аэратор': 'трубчатые строительные материалы сантехника', 
           'втулка': 'трубчатые строительные материалы сантехника', 
          'сифон': 'трубчатые строительные материалы сантехника', 
           'гофрированный': 'трубчатые строительные материалы сантехника',
          'смеситель': 'трубчатые строительные материалы сантехника', 
          'клапан': 'трубчатые строительные материалы сантехника', 
           'гофротрубка': 'трубчатые строительные материалы сантехника',
          'кран': 'трубчатые строительные материалы сантехника', 'сантехника': 'трубчатые строительные материалы сантехника',
          'шланг': 'трубчатые строительные материалы сантехника',
          'унитаза': 'трубчатые строительные материалы сантехника', 
           'стоки':'трубчатые строительные материалы сантехника', 'cифон': 'трубчатые строительные материалы сантехника',
          'сантех':'трубчатые строительные материалы сантехника', 'излив': 'трубчатые строительные материалы сантехника',
          'арматура': 'трубчатые строительные материалы сантехника','умывальник':'трубчатые строительные материалы сантехника',
          'лейка': 'трубчатые строительные материалы сантехника','дюб': 'дюбель'}
# шамп: шампунь шампанское

# %% [markdown]
# Так мы получаем предобработанный текст.

# %%
dct_, tr_, = prepare(train, perevod, l, maslin, prazdnik, do_lemma=False)
# Out:
# STEP 1
# STEP 2
# STEP 3
# STEP 4
# STEP 5
# STEP 6
# MAPPING....

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# Так мы обучаем `Word2Vec`

# %%
from gensim.models import Word2Vec
import pickle

# %%
vocab_tokemizer = {k: w.split(' ') for k, w in enumerate(tr_['preprocess'])}

# %%
model = Word2Vec(list(vocab_tokemizer.values()), # data for model to train on
                 size=300,         # embedding vector size
                 min_count=7,     # consider words that occured at least 5 times
                 window=7).wv     # define context as a 3-word window around the target word

# %%
pickle.dump(model, open('word2vec', 'wb'))

# %% [markdown]
# Откроем обученный нами `word2vec`

# %%
m = pickle.load(open('word2vec', 'rb'))

# %% [markdown]
# Получаем эмбеддинги предложения.

# %%
def question_to_vec(question, embeddings, dim=300, first=True):
    """
        question: строка
        embeddings: наше векторное представление
        dim: размер любого вектора в нашем представлении
        
        return: векторное представление для вопроса
    """
    words = question.split(' ') #your code
    # убрать знак вопроса, если он есть
    n_known = 0
    result = np.array([0] * dim, dtype=float)
    
    if first:
        word = words[0]
        if word in embeddings:
            result += embeddings[word] #your code
            n_known += 1
    else:
        for word in words:
            if word in embeddings:
                result += embeddings[word] #your code
                n_known += 1
            
    if n_known != 0:
        return result / n_known #your code
    else:
        return result

# %%
unique_items = train_data.drop_duplicates('item_name')
dct2_, tr2_, = prepare(unique_items, perevod, l, maslin, prazdnik, do_lemma=False)
# Out:
# STEP 1
# STEP 2
# STEP 3
# STEP 4
# STEP 5
# STEP 6
# MAPPING....

# %% [markdown]
# Примеры предобработки текста:

# %%
unique_items.loc[72]['item_name'], unique_items.loc[72]['preprocess']
# Out:
# ('Спинки варено-копченые из мяса ЦБ в/у охладенные',
#  'спинки варено копченые из мяса цыпленок бройлер вакуумная упаковка охладенные')

# %%
unique_items.loc[221]['item_name'], unique_items.loc[221]['preprocess']
# Out:
# ('Брюки трик. женские', 'брюки трикотажные женские')

# %% [markdown]
# Полуичим эмбеддинги.

# %%
# %%time

X = np.array([question_to_vec(question=question, embeddings=m, dim=300, first=False) for question in tr2_['preprocess']])
y = unique_items['category_id'].values
# Out:
# Wall time: 3.4 s

# %% [markdown]
# Составим таблицу эмбеддингов.

# %%
dat = pd.DataFrame(np.concatenate((X, 
                                   tr2_[['receipt_dayofweek', 'item_quantity', 'item_price', 'item_nds_rate']].values, 
                                   y[:, np.newaxis]), axis=1))
columns = [f'feature_{x}' for x in np.arange(0, 300)] + \
['receipt_dayofweek', 'item_quantity', 'item_price', 'item_nds_rate'] + \
['category_id']
dat.columns = columns

# %%
dat.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.054561  -0.392966   0.410688   0.116836   0.989019   1.157157
# 1   0.376635  -1.049812   1.021654  -0.610256  -0.561202  -0.090528
# 2   0.020388  -1.286427   0.521235  -1.633261   0.155876  -0.660067
# 3  -0.993593   0.944048  -0.093030  -0.828796  -0.848058   0.692314
# 4   1.044952   0.706317   0.509403   0.475204   1.119540   1.249804
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_295  feature_296  \
# 0   1.632287  -0.352680  -0.509084   0.689676  ...     1.274330    -1.676105
# 1   1.225579   0.942012  -0.220868   1.147172  ...    -1.592884    -1.578708
# 2   0.093485   0.784330   0.392229  -0.063603  ...    -1.068598    -1.367852
# 3   0.216841  -1.680906  -1.517059  -0.495888  ...    -0.079874     0.545516
# 4   1.099545  -0.517986  -0.934430   0.830007  ...     1.256626    -0.397411
#
#    feature_297  feature_298  feature_299  receipt_dayofweek  item_quantity  \
# 0    -0.193540     1.174354     0.899041                6.0            2.0
# 1     0.510537    -0.795046     0.296348                4.0            1.0
# 2    -0.088262    -1.153419     0.858392                4.0            1.0
# 3     0.435811    -0.417459     0.429165                5.0            1.0
# 4     0.466691     0.839089     0.332216                3.0            1.0
#
#    item_price  item_nds_rate  category_id
# 0         8.0            2.0         78.0
# 1         4.0            1.0         71.0
# 2         4.0            1.0         71.0
# 3        12.0            1.0         70.0
# 4         7.0           -1.0         84.0
#
# [5 rows x 305 columns]

# %% [markdown]
# На этом можно обучать модели, например `KNN`.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.metrics import f1_score

# %%
knn = KNeighborsClassifier(n_neighbors=9)
folds = KFold(8, 
              shuffle=True, 
              random_state=0)

# %%
predicts = cross_val_predict(knn, 
                             X, 
                             y, 
                             cv=folds, 
                             n_jobs=8, 
                             method='predict')

# %%
score = f1_score(y, predicts, average='weighted')
print(score)
# Out:
# 0.7549749233089824

# %% [markdown]
# Посмотрим вообще на эмбеддинги.

# %%
m.most_similar('кефир')
# Out:
# [('ряженка', 0.718873143196106),
#  ('варенец', 0.58260178565979),
#  ('снежок', 0.4844396710395813),
#  ('ультрапастеризованное', 0.46592074632644653),
#  ('биоматрикс', 0.4627859890460968),
#  ('простокваша', 0.43150943517684937),
#  ('бифидок', 0.40915602445602417),
#  ('питьевое', 0.39816442131996155),
#  ('кефирный', 0.3964994251728058),
#  ('пастеризованное', 0.38972562551498413)]

# %%
m.most_similar('гайка')
# Out:
# [('болт', 0.7063924074172974),
#  ('шпилька', 0.5963376760482788),
#  ('гайкой', 0.5931398868560791),
#  ('шплинт', 0.5835789442062378),
#  ('резьбовая', 0.581788957118988),
#  ('оцинкованная', 0.5693467855453491),
#  ('din', 0.561095118522644),
#  ('контргайка', 0.5568018555641174),
#  ('гровер', 0.5169054269790649),
#  ('нейлоновой', 0.5123203992843628)]

# %% [markdown]
# ## SVMClassifier + TFIDF

# %% [markdown]
# Так мы делаем предсказание с помощью модели из пункта `III.3`

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
unique_items = train_data.drop_duplicates('item_name')
d, x =  prepare(unique_items, perevod, l, maslin, prazdnik, do_lemma=False)

tfidf = TfidfVectorizer(
    max_features=800000, 
    ngram_range=(1, 6), 
    stop_words ='russian',
    analyzer="char_wb", 
    norm = 'l2'
)

x['new'] = x['preprocess'] + ' ' + x['item_name']
X_train = tfidf.fit_transform(x.new)
y_train = x['category_id']
clf = LinearSVC(cl)
folds = KFold(8, 
              shuffle=True, 
              random_state=0)
# Out:
# STEP 1
# STEP 2
# STEP 3
# STEP 4
# STEP 5
# STEP 6
# MAPPING....
# c:\users\shiro\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\users\shiro\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
clf.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
predicts = cross_val_predict(clf, 
                             X_train, 
                             y_train, 
                             cv=folds, 
                             n_jobs=8, 
                             method='predict')

# %%
pickle.dump(clf, open('new_sol_2/clf_task1', 'wb'))
pickle.dump(tfidf, open('new_sol_2/tfidf', 'wb'))

# %%
from sklearn.metrics import f1_score

score = f1_score(y_train, predicts, average='weighted')
print(score)
# Out:
# 0.845884989392697

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      2356
#            1       0.93      0.89      0.91        28
#            2       0.97      0.89      0.92       316
#            3       0.88      0.87      0.88       109
#            4       0.70      0.64      0.67       225
#            6       0.55      0.38      0.44        64
#            7       0.94      0.98      0.96       224
#            9       0.90      0.98      0.94       104
#           11       0.60      0.53      0.56        47
#           12       0.78      0.69      0.73       182
#           13       0.71      0.59      0.65        37
#           19       0.74      0.50      0.60        74
#           20       0.98      0.88      0.93        59
#           24       0.65      0.47      0.55        68
#           26       0.20      0.09      0.13        22
#           27       0.72      0.68      0.70        38
#           29       0.78      0.89      0.83       129
#           30       0.78      0.75      0.77       296
#           31       0.39      0.18      0.25        38
#           35       0.88      0.60      0.71        25
#           36       0.82      0.65      0.72       189
#           37       0.73      0.52      0.60       124
#           38       0.92      0.96      0.94      2269
#           39       0.93      0.64      0.76        42
#           40       0.79      0.85      0.82       552
#           41       0.71      0.43      0.54        79
#           42       0.73      0.61      0.67        95
#           43       0.91      0.83      0.87       304
#           45       0.84      0.83      0.83       312
#           46       0.83      0.33      0.48        15
#           49       0.84      0.81      0.83       308
#           50       0.71      0.73      0.72       218
#           51       0.73      0.67      0.70       323
#           52       0.73      0.76      0.75       236
#           53       0.95      0.98      0.96       126
#           54       0.84      0.83      0.84        89
#           55       1.00      1.00      1.00        47
#           56       0.86      0.71      0.77        34
#           57       0.87      0.85      0.86       246
#           58       1.00      0.99      0.99        67
#           60       0.95      0.89      0.92       180
#           61       0.88      0.90      0.89      1058
#           62       0.82      0.79      0.81       155
#           66       0.88      0.92      0.90       237
#           67       0.83      0.88      0.86       306
#           68       0.84      0.87      0.85       175
#           69       0.83      0.77      0.80       441
#           70       0.84      0.89      0.86       887
#           71       0.81      0.83      0.82      4771
#           72       0.87      0.79      0.83       288
#           73       0.86      0.78      0.82      1109
#           74       0.90      0.91      0.90      1011
#           75       0.83      0.80      0.81       742
#           76       0.87      0.83      0.85       568
#           77       0.85      0.85      0.85      1190
#           78       0.93      0.95      0.94      2869
#           79       0.76      0.78      0.77       815
#           80       0.87      0.92      0.89      1850
#           81       0.87      0.87      0.87      1134
#           82       0.79      0.80      0.79       547
#           83       0.92      0.94      0.93      2865
#           84       0.91      0.95      0.92      7094
#           85       0.85      0.76      0.80       674
#           90       0.48      0.50      0.49        50
#           92       0.83      0.81      0.82       149
#           96       0.62      0.56      0.59        45
#           97       0.83      0.38      0.53        13
#          100       0.71      0.36      0.48        14
#          101       0.60      0.53      0.56        17
#          102       0.65      0.79      0.71        19
#          103       0.70      0.44      0.54        96
#          105       0.66      0.58      0.61       132
#          106       0.61      0.39      0.47        36
#          107       0.71      0.70      0.71       235
#          108       0.74      0.65      0.70        75
#          109       0.80      0.72      0.76       230
#          111       0.50      0.67      0.57        58
#          114       0.69      0.64      0.66       433
#          115       0.69      0.64      0.67       169
#          117       0.83      0.83      0.83       533
#          118       0.62      0.68      0.65       314
#          120       0.73      0.59      0.65       314
#          128       0.82      0.83      0.83        90
#          130       0.81      0.86      0.83       877
#          133       0.77      0.72      0.75       178
#          138       0.71      0.49      0.58        91
#          139       0.73      0.71      0.72       551
#          140       0.74      0.52      0.61       331
#          145       0.95      0.93      0.94       480
#          150       0.85      0.65      0.74        81
#          163       0.51      0.65      0.57        43
#          164       0.63      0.36      0.46        74
#          167       0.74      0.53      0.62        91
#          177       0.76      0.73      0.75       119
#          203       0.70      0.51      0.59        59
#          204       0.52      0.51      0.51      1146
#
#     accuracy                           0.85     48225
#    macro avg       0.78      0.71      0.74     48225
# weighted avg       0.85      0.85      0.85     48225

# %% [markdown]
# Видим, что есть отличная разделимость примерно половины классов, но на ухудшают результат очень плохо разделимые классые - например класс `26` - органайзеры, ножницы, бумага - очень перекрывающиеся c другими классами. В этом и проблема представления `tfidf` - контекст и порядок слов не учитываются. Поэтому, нужно применять другие модели. А какие - узнаем у победителей.
#
# Спасибо!
